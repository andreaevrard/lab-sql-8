# %% [markdown]
# # Lab | SQL Queries 8
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals. You have been using this database for a couple labs already, but if you need to get the data again, refer to the official [installation link](https://dev.mysql.com/doc/sakila/en/sakila-installation.html).
#
# The database is structured as follows:
# ![DB schema](https://education-team-2020.s3-eu-west-1.amazonaws.com/data-analytics/database-sakila-schema.png)
#
# ### Instructions
#
# 1. Rank films by length (filter out the rows with nulls or zeros in length column). Select only columns title, length and rank in your output.
# 2. Rank films by length within the `rating` category (filter out the rows with nulls or zeros in length column). In your output, only select the columns title, length, rating and rank.
# 3. How many films are there for each of the categories in the category table? **Hint**: Use appropriate join between the tables "category" and "film_category".
# 4. Which actor has appeared in the most films? **Hint**: You can create a join between the tables "actor" and "film actor" and count the number of times an actor appears.
# 5. Which is the most active customer (the customer that has rented the most number of films)? **Hint**: Use appropriate join between the tables "customer" and "rental" and count the `rental_id` for each customer.
#
# **Bonus**: Which is the most rented film? (The answer is Bucket Brotherhood).
#
# This query might require using more than one join statement. Give it a try. We will talk about queries with multiple join statements later in the lessons.
#
# **Hint**: You can use join between three tables - "Film", "Inventory", and "Rental" and count the *rental ids* for each film.

# %% [markdown]
# # Your solution here:

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input

# %% [markdown]
# ##### Prepare SQL connection

# %%
password = getpass.getpass()
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)
# %reload_ext sql
# %sql {connection_string}
# Out:
#  ········

# %% [markdown]
# ##### 1. Rank films by length (filter out the rows with nulls or zeros in length column). Select only columns title, length and rank in your output.

# %%
# %%sql
# select title, length, dense_rank() over (order by length) as 'rank'
# from sakila.film
# where length>0 and length is not null;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 1000 rows affected.
# [('ALIEN CENTER', 46, 1),
#  ('IRON MOON', 46, 1),
#  ('KWAI HOMEWARD', 46, 1),
#  ('LABYRINTH LEAGUE', 46, 1),
#  ('RIDGEMONT SUBMARINE', 46, 1),
#  ('DIVORCE SHINING', 47, 2),
#  ('DOWNHILL ENOUGH', 47, 2),
#  ('HALLOWEEN NUTS', 47, 2),
#  ('HANOVER GALAXY', 47, 2),
#  ('HAWK CHILL', 47, 2),
#  ('SHANGHAI TYCOON', 47, 2),
#  ('SUSPECTS QUILLS', 47, 2),
#  ('ACE GOLDFINGER', 48, 3),
#  ('HEAVEN FREEDOM', 48, 3),
#  ('MIDSUMMER GROUNDHOG', 48, 3),
#  ('NOTTING SPEAKEASY', 48, 3),
#  ('ODDS BOOGIE', 48, 3),
#  ('PARADISE SABRINA', 48, 3),
#  ('PELICAN COMFORTS', 48, 3),
#  ('RUSH GOODFELLAS', 48, 3),
#  ('STEPMOM DREAM', 48, 3),
#  ('SUNSET RACER', 48, 3),
#  ('VALENTINE VANISHING', 48, 3),
#  ('DOORS PRESIDENT', 49, 4),
#  ('GROSSE WONDERFUL', 49, 4),
#  ('HEAVENLY GUN', 49, 4),
#  ('HOOK CHARIOTS', 49, 4),
#  ('HURRICANE AFFAIR', 49, 4),
#  ('ADAPTATION HOLES', 50, 5),
#  ('BLUES INSTINCT', 50, 5),
#  ('CROSSING DIVORCE', 50, 5),
#  ('LION UNCUT', 50, 5),
#  ('MUPPET MILE', 50, 5),
#  ('NATURAL STOCK', 50, 5),
#  ('PILOT HOOSIERS', 50, 5),
#  ('SMOKING BARBARELLA', 50, 5),
#  ('ZORRO ARK', 50, 5),
#  ('CHAMPION FLATLINERS', 51, 6),
#  ('DEEP CRUSADE', 51, 6),
#  ('ENGLISH BULWORTH', 51, 6),
#  ('EXCITEMENT EVE', 51, 6),
#  ('FRISCO FORREST', 51, 6),
#  ('HALL CASSIDY', 51, 6),
#  ('SIMON NORTH', 51, 6),
#  ('CADDYSHACK JEDI', 52, 7),
#  ('HARPER DYING', 52, 7),
#  ('LUST LOCK', 52, 7),
#  ('SIDE ARK', 52, 7),
#  ('SPARTACUS CHEAPER', 52, 7),
#  ('TROJAN TOMORROW', 52, 7),
#  ('WESTWARD SEABISCUIT', 52, 7),
#  ('BENEATH RUSH', 53, 8),
#  ('CABIN FLASH', 53, 8),
#  ('GUMP DATE', 53, 8),
#  ('MAGNIFICENT CHITTY', 53, 8),
#  ('MOVIE SHAKESPEARE', 53, 8),
#  ('PRIMARY GLASS', 53, 8),
#  ('SUMMER SCARFACE', 53, 8),
#  ('TEQUILA PAST', 53, 8),
#  ('THIN SAGEBRUSH', 53, 8),
#  ('AIRPORT POLLOCK', 54, 9),
#  ('GO PURPLE', 54, 9),
#  ('JUGGLER HARDLY', 54, 9),
#  ('KILL BROTHERHOOD', 54, 9),
#  ('OCTOBER SUBMARINE', 54, 9),
#  ('SENSE GREEK', 54, 9),
#  ('COAST RAINBOW', 55, 10),
#  ('WOLVES DESIRE', 55, 10),
#  ('BRIDE INTRIGUE', 56, 11),
#  ('CUPBOARD SINNERS', 56, 11),
#  ('DESTINY SATURDAY', 56, 11),
#  ('GOODFELLAS SALUTE', 56, 11),
#  ('MATRIX SNOWMAN', 56, 11),
#  ('ALTER VICTORY', 57, 12),
#  ('CRANES RESERVOIR', 57, 12),
#  ('DAWN POND', 57, 12),
#  ('DOCTOR GRAIL', 57, 12),
#  ('MOSQUITO ARMAGEDDON', 57, 12),
#  ('NOON PAPI', 57, 12),
#  ('STORM HAPPINESS', 57, 12),
#  ('CLOSER BANG', 58, 13),
#  ('DANCES NONE', 58, 13),
#  ('FANTASY TROOPERS', 58, 13),
#  ('JEKYLL FROGMEN', 58, 13),
#  ('OKLAHOMA JUMANJI', 58, 13),
#  ('RINGS HEARTBREAKERS', 58, 13),
#  ('SUPER WYOMING', 58, 13),
#  ('COMMANDMENTS EXPRESS', 59, 14),
#  ('DAUGHTER MADIGAN', 59, 14),
#  ('HEARTBREAKERS BRIGHT', 59, 14),
#  ('INTERVIEW LIAISONS', 59, 14),
#  ('JET NEIGHBORS', 59, 14),
#  ('LEGEND JEDI', 59, 14),
#  ('MINORITY KISS', 59, 14),
#  ('VISION TORQUE', 59, 14),
#  ('WHISPERER GIANT', 59, 14),
#  ('BUBBLE GROSSE', 60, 15),
#  ('JERSEY SASSY', 60, 15),
#  ('MOCKINGBIRD HOLLYWOOD', 60, 15),
#  ('PHANTOM GLORY', 60, 15),
#  ('PITY BOUND', 60, 15),
#  ('ROOM ROMAN', 60, 15),
#  ('SHAKESPEARE SADDLE', 60, 15),
#  ('SMILE EARRING', 60, 15),
#  ('BIRDS PERDITION', 61, 16),
#  ('BULWORTH COMMANDMENTS', 61, 16),
#  ('CAMELOT VACATION', 61, 16),
#  ('CASSIDY WYOMING', 61, 16),
#  ('CHINATOWN GLADIATOR', 61, 16),
#  ('DRIFTER COMMANDMENTS', 61, 16),
#  ('POLISH BROOKLYN', 61, 16),
#  ('RESERVOIR ADAPTATION', 61, 16),
#  ('TROUBLE DATE', 61, 16),
#  ('WATERFRONT DELIVERANCE', 61, 16),
#  ('AIRPLANE SIERRA', 62, 17),
#  ('ARABIA DOGMA', 62, 17),
#  ('HANGING DEEP', 62, 17),
#  ('MARS ROMAN', 62, 17),
#  ('SNOWMAN ROLLERCOASTER', 62, 17),
#  ('UNBREAKABLE KARATE', 62, 17),
#  ('ALADDIN CALENDAR', 63, 18),
#  ('BONNIE HOLOCAUST', 63, 18),
#  ('BORROWERS BEDAZZLED', 63, 18),
#  ('BOULEVARD MOB', 63, 18),
#  ('BUNCH MINDS', 63, 18),
#  ('DINOSAUR SECRETARY', 63, 18),
#  ('FORREST SONS', 63, 18),
#  ('INTOLERABLE INTENTIONS', 63, 18),
#  ('REUNION WITCHES', 63, 18),
#  ('CRAFT OUTFIELD', 64, 19),
#  ('DESERT POSEIDON', 64, 19),
#  ('METROPOLIS COMA', 64, 19),
#  ('MILE MULAN', 64, 19),
#  ('NOVOCAINE FLIGHT', 64, 19),
#  ('SLEEPLESS MONSOON', 64, 19),
#  ('TAXI KICK', 64, 19),
#  ('TRIP NEWTON', 64, 19),
#  ('VICTORY ACADEMY', 64, 19),
#  ('BARBARELLA STREETCAR', 65, 20),
#  ('CLUB GRAFFITI', 65, 20),
#  ('CONFESSIONS MAGUIRE', 65, 20),
#  ('FREDDY STORM', 65, 20),
#  ('HUNTING MUSKETEERS', 65, 20),
#  ('LOVELY JINGLE', 65, 20),
#  ('PATRIOT ROMAN', 65, 20),
#  ('CHARADE DUFFEL', 66, 21),
#  ('EVE RESURRECTION', 66, 21),
#  ('BUTCH PANTHER', 67, 22),
#  ('COMANCHEROS ENEMY', 67, 22),
#  ('EGG IGBY', 67, 22),
#  ('LADY STAGE', 67, 22),
#  ('LONELY ELEPHANT', 67, 22),
#  ('NORTH TEQUILA', 67, 22),
#  ('SHOOTIST SUPERFLY', 67, 22),
#  ('SILENCE KANE', 67, 22),
#  ('ARK RIDGEMONT', 68, 23),
#  ('DIVIDE MONSTER', 68, 23),
#  ('DOOM DANCING', 68, 23),
#  ('HUMAN GRAFFITI', 68, 23),
#  ('TOMATOES HELLFIGHTERS', 68, 23),
#  ('CRUELTY UNFORGIVEN', 69, 24),
#  ('FLYING HOOK', 69, 24),
#  ('HEAD STRANGER', 69, 24),
#  ('HOLLYWOOD ANONYMOUS', 69, 24),
#  ('LEBOWSKI SOLDIERS', 69, 24),
#  ('TIMBERLAND SKY', 69, 24),
#  ('CANDIDATE PERDITION', 70, 25),
#  ('CHANCE RESURRECTION', 70, 25),
#  ('CLUE GRAIL', 70, 25),
#  ('COLDBLOODED DARLING', 70, 25),
#  ('GUNFIGHT MOON', 70, 25),
#  ('LOUISIANA HARRY', 70, 25),
#  ('WEDDING APOLLO', 70, 25),
#  ('BLOOD ARGONAUTS', 71, 26),
#  ('CHARIOTS CONSPIRACY', 71, 26),
#  ('KNOCK WARLOCK', 71, 26),
#  ('MANNEQUIN WORST', 71, 26),
#  ('PRINCESS GIANT', 71, 26),
#  ('TEMPLE ATTRACTION', 71, 26),
#  ('TRAIN BUNCH', 71, 26),
#  ('BOWFINGER GABLES', 72, 27),
#  ('FICTION CHRISTMAS', 72, 27),
#  ('HARDLY ROBBERS', 72, 27),
#  ('MAUDE MOD', 72, 27),
#  ('BEDAZZLED MARRIED', 73, 28),
#  ('BRIGHT ENCOUNTERS', 73, 28),
#  ('BROTHERHOOD BLANKET', 73, 28),
#  ('FRIDA SLIPPER', 73, 28),
#  ('GODFATHER DIARY', 73, 28),
#  ('MUSKETEERS WAIT', 73, 28),
#  ('RANDOM GO', 73, 28),
#  ('REBEL AIRPORT', 73, 28),
#  ('SALUTE APOLLO', 73, 28),
#  ('STREETCAR INTENTIONS', 73, 28),
#  ('VALLEY PACKER', 73, 28),
#  ('WAKE JAWS', 73, 28),
#  ('ANGELS LIFE', 74, 29),
#  ('INFORMER DOUBLE', 74, 29),
#  ('JUMPING WRATH', 74, 29),
#  ('LUKE MUMMY', 74, 29),
#  ('MAGUIRE APACHE', 74, 29),
#  ('MODERN DORADO', 74, 29),
#  ('PEARL DESTINY', 74, 29),
#  ('RAINBOW SHOCK', 74, 29),
#  ('SILVERADO GOLDFINGER', 74, 29),
#  ('SNATCHERS MONTEZUMA', 74, 29),
#  ('TEEN APOLLO', 74, 29),
#  ('WORKING MICROCOSMOS', 74, 29),
#  ('BALLOON HOMEWARD', 75, 30),
#  ('CALIFORNIA BIRDS', 75, 30),
#  ('FIDDLER LOST', 75, 30),
#  ('HELLFIGHTERS SIERRA', 75, 30),
#  ('LOVER TRUMAN', 75, 30),
#  ('NETWORK PEAK', 75, 30),
#  ('NEWTON LABYRINTH', 75, 30),
#  ('SATISFACTION CONFIDENTIAL', 75, 30),
#  ('STAMPEDE DISTURBING', 75, 30),
#  ('WIZARD COLDBLOODED', 75, 30),
#  ('BOONDOCK BALLROOM', 76, 31),
#  ('COMFORTS RUSH', 76, 31),
#  ('DESIRE ALIEN', 76, 31),
#  ('DESTINATION JERK', 76, 31),
#  ('HAUNTED ANTITRUST', 76, 31),
#  ('ORANGE GRAPES', 76, 31),
#  ('VILLAIN DESPERATE', 76, 31),
#  ('BERETS AGENT', 77, 32),
#  ('ENEMY ODDS', 77, 32),
#  ('FELLOWSHIP AUTUMN', 77, 32),
#  ('MEMENTO ZOOLANDER', 77, 32),
#  ('MOD SECRETARY', 77, 32),
#  ('PICKUP DRIVING', 77, 32),
#  ('HOLIDAY GAMES', 78, 33),
#  ('INSIDER ARIZONA', 78, 33),
#  ('LANGUAGE COWBOY', 78, 33),
#  ('UNFAITHFUL KILL', 78, 33),
#  ('VOYAGE LEGALLY', 78, 33),
#  ('WATCH TRACY', 78, 33),
#  ('AMELIE HELLFIGHTERS', 79, 34),
#  ('ISHTAR ROCKETEER', 79, 34),
#  ('MOULIN WAKE', 79, 34),
#  ('SHOCK CABIN', 79, 34),
#  ('SPIKING ELEMENT', 79, 34),
#  ('WEREWOLF LOLA', 79, 34),
#  ('FLAMINGOS CONNECTICUT', 80, 35),
#  ('GARDEN ISLAND', 80, 35),
#  ('LOSER HUSTLER', 80, 35),
#  ('MEET CHOCOLATE', 80, 35),
#  ('PEAK FOREVER', 80, 35),
#  ('SADDLE ANTITRUST', 80, 35),
#  ('SEA VIRGIN', 80, 35),
#  ('SHAWSHANK BUBBLE', 80, 35),
#  ('TURN STAR', 80, 35),
#  ('WAR NOTTING', 80, 35),
#  ('CLASH FREDDY', 81, 36),
#  ('DESPERATE TRAINSPOTTING', 81, 36),
#  ('ROMAN PUNK', 81, 36),
#  ('ALONE TRIP', 82, 37),
#  ('ANYTHING SAVANNAH', 82, 37),
#  ('FROST HEAD', 82, 37),
#  ('PERFECT GROOVE', 82, 37),
#  ('RAIDERS ANTITRUST', 82, 37),
#  ('REIGN GENTLEMEN', 82, 37),
#  ('TYCOON GATHERING', 82, 37),
#  ('ATTRACTION NEWTON', 83, 38),
#  ('FUGITIVE MAGUIRE', 83, 38),
#  ('HUSTLER PARTY', 83, 38),
#  ('MOON BUNCH', 83, 38),
#  ('NONE SPIKING', 83, 38),
#  ('WARLOCK WEREWOLF', 83, 38),
#  ('DAISY MENAGERIE', 84, 39),
#  ('GONE TROUBLE', 84, 39),
#  ('GUYS FALCON', 84, 39),
#  ('HIGH ENCINO', 84, 39),
#  ('HONEY TIES', 84, 39),
#  ('IDOLS SNATCHERS', 84, 39),
#  ('ISLAND EXORCIST', 84, 39),
#  ('JEEPERS WEDDING', 84, 39),
#  ('PACKER MADIGAN', 84, 39),
#  ('PLUTO OLEANDER', 84, 39),
#  ('SAVANNAH TOWN', 84, 39),
#  ('SLING LUKE', 84, 39),
#  ('UPTOWN YOUNG', 84, 39),
#  ('AMISTAD MIDSUMMER', 85, 40),
#  ('BEVERLY OUTLAW', 85, 40),
#  ('BLACKOUT PRIVATE', 85, 40),
#  ('CANYON STOCK', 85, 40),
#  ('CASABLANCA SUPER', 85, 40),
#  ('EARTH VISION', 85, 40),
#  ('EGYPT TENENBAUMS', 85, 40),
#  ('ENDING CROWDS', 85, 40),
#  ('GHOST GROUNDHOG', 85, 40),
#  ('GRAIL FRANKENSTEIN', 85, 40),
#  ('LOLA AGENT', 85, 40),
#  ('OZ LIAISONS', 85, 40),
#  ('STAGE WORLD', 85, 40),
#  ('VARSITY TRIP', 85, 40),
#  ('WASTELAND DIVINE', 85, 40),
#  ('WINDOW SIDE', 85, 40),
#  ('WONKA SEA', 85, 40),
#  ('ACADEMY DINOSAUR', 86, 41),
#  ('ANNIE IDENTITY', 86, 41),
#  ('GANDHI KWAI', 86, 41),
#  ('MIDNIGHT WESTWARD', 86, 41),
#  ('YENTL IDAHO', 86, 41),
#  ('BANG KWAI', 87, 42),
#  ('CHEAPER CLYDE', 87, 42),
#  ('CONGENIALITY QUEST', 87, 42),
#  ('DEVIL DESIRE', 87, 42),
#  ('SLEUTH ORIENT', 87, 42),
#  ('TREATMENT JEKYLL', 87, 42),
#  ('DETAILS PACKER', 88, 43),
#  ('HOLY TADPOLE', 88, 43),
#  ('PURPLE MOVIE', 88, 43),
#  ('TERMINATOR CLUB', 88, 43),
#  ('BEAST HUNCHBACK', 89, 44),
#  ('BUTTERFLY CHOCOLAT', 89, 44),
#  ('DARES PLUTO', 89, 44),
#  ('GLEAMING JAWBREAKER', 89, 44),
#  ('PULP BEVERLY', 89, 44),
#  ('ROOTS REMEMBER', 89, 44),
#  ('BASIC EASY', 90, 45),
#  ('CIRCUS YOUTH', 90, 45),
#  ('FORWARD TEMPLE', 90, 45),
#  ('SECRET GROUNDHOG', 90, 45),
#  ('VERTIGO NORTHWEST', 90, 45),
#  ('ANTHEM LUKE', 91, 46),
#  ('FATAL HAUNTED', 91, 46),
#  ('FIGHT JAWBREAKER', 91, 46),
#  ('LICENSE WEEKEND', 91, 46),
#  ('TARZAN VIDEOTAPE', 91, 46),
#  ('TITANS JERK', 91, 46),
#  ('ANACONDA CONFESSIONS', 92, 47),
#  ('APACHE DIVINE', 92, 47),
#  ('CARIBBEAN LIBERTY', 92, 47),
#  ('CORE SUIT', 92, 47),
#  ('ENCOUNTERS CURTAIN', 92, 47),
#  ('KANE EXORCIST', 92, 47),
#  ('MYSTIC TRUMAN', 92, 47),
#  ('NATIONAL STORY', 92, 47),
#  ('OPPOSITE NECKLACE', 92, 47),
#  ('SUNDANCE INVASION', 92, 47),
#  ('TRUMAN CRAZY', 92, 47),
#  ('BILL OTHERS', 93, 48),
#  ('GOLDFINGER SENSIBILITY', 93, 48),
#  ('GREATEST NORTH', 93, 48),
#  ('HILLS NEIGHBORS', 93, 48),
#  ('PANKY SUBMARINE', 93, 48),
#  ('SHANE DARKNESS', 93, 48),
#  ('STING PERSONAL', 93, 48),
#  ('SUICIDES SILENCE', 93, 48),
#  ('ALICE FANTASIA', 94, 49),
#  ('DISTURBING SCARFACE', 94, 49),
#  ('FULL FLATLINERS', 94, 49),
#  ('STONE FIRE', 94, 49),
#  ('CLUELESS BUCKET', 95, 50),
#  ('HORN WORKING', 95, 50),
#  ('DRUMS DYNAMITE', 96, 51),
#  ('EARLY HOME', 96, 51),
#  ('EXPENDABLE STALLION', 97, 52),
#  ('INVASION CYCLONE', 97, 52),
#  ('LUCKY FLYING', 97, 52),
#  ('REAR TRADING', 97, 52),
#  ('BOUND CHEAPER', 98, 53),
#  ('EARRING INSTINCT', 98, 53),
#  ('FEUD FROGMEN', 98, 53),
#  ('LOST BIRD', 98, 53),
#  ('MADRE GABLES', 98, 53),
#  ('PREJUDICE OLEANDER', 98, 53),
#  ('SENSIBILITY REAR', 98, 53),
#  ('WISDOM WORKER', 98, 53),
#  ('ARMAGEDDON LOST', 99, 54),
#  ('DARKNESS WAR', 99, 54),
#  ('FRENCH HOLIDAY', 99, 54),
#  ('PATIENT SISTER', 99, 54),
#  ('PERDITION FARGO', 99, 54),
#  ('PET HAUNTING', 99, 54),
#  ('SABRINA MIDNIGHT', 99, 54),
#  ('TENENBAUMS COMMAND', 99, 54),
#  ('BEHAVIOR RUNAWAY', 100, 55),
#  ('BILKO ANONYMOUS', 100, 55),
#  ('DELIVERANCE MULHOLLAND', 100, 55),
#  ('DIVINE RESURRECTION', 100, 55),
#  ('FLATLINERS KILLER', 100, 55),
#  ('GUN BONNIE', 100, 55),
#  ('HAPPINESS UNITED', 100, 55),
#  ('HYDE DOCTOR', 100, 55),
#  ('PIRATES ROXANNE', 100, 55),
#  ('PUNK DIVORCE', 100, 55),
#  ('WITCHES PANIC', 100, 55),
#  ('WYOMING STORM', 100, 55),
#  ('CHOCOLAT HARRY', 101, 56),
#  ('CIDER DESIRE', 101, 56),
#  ('DWARFS ALTER', 101, 56),
#  ('GHOSTBUSTERS ELF', 101, 56),
#  ('ROOF CHAMPION', 101, 56),
#  ('RUNNER MADIGAN', 101, 56),
#  ('ZOOLANDER FICTION', 101, 56),
#  ('BOILED DARES', 102, 57),
#  ('FALCON VOLUME', 102, 57),
#  ('GIANT TROOPERS', 102, 57),
#  ('HEAVYWEIGHTS BEAST', 102, 57),
#  ('JEOPARDY ENCINO', 102, 57),
#  ('OPUS ICE', 102, 57),
#  ('PANIC CLUB', 102, 57),
#  ('ROBBERS JOON', 102, 57),
#  ('ROCK INSTINCT', 102, 57),
#  ('SCARFACE BANG', 102, 57),
#  ('TREASURE COMMAND', 102, 57),
#  ('BIRDCAGE CASPER', 103, 58),
#  ('BLINDNESS GUN', 103, 58),
#  ('FIREHOUSE VIETNAM', 103, 58),
#  ('GLASS DYING', 103, 58),
#  ('HOMEWARD CIDER', 103, 58),
#  ('IMPOSSIBLE PREJUDICE', 103, 58),
#  ('MOTHER OLEANDER', 103, 58),
#  ('PINOCCHIO SIMON', 103, 58),
#  ('STRANGELOVE DESIRE', 103, 58),
#  ('CROW GREASE', 104, 59),
#  ('DATE SPEED', 104, 59),
#  ('FEATHERS METAL', 104, 59),
#  ('MERMAID INSECTS', 104, 59),
#  ('SHIP WONDERLAND', 104, 59),
#  ('TITANIC BOONDOCK', 104, 59),
#  ('HUNGER ROOF', 105, 60),
#  ('JOON NORTHWEST', 105, 60),
#  ('MICROCOSMOS PARADISE', 105, 60),
#  ('MOB DUFFEL', 105, 60),
#  ('WON DARES', 105, 60),
#  ('ZHIVAGO CORE', 105, 60),
#  ('BED HIGHBALL', 106, 61),
#  ('DALMATIONS SWEDEN', 106, 61),
#  ('DEER VIRGINIAN', 106, 61),
#  ('GASLIGHT CRUSADE', 106, 61),
#  ('PRIVATE DROP', 106, 61),
#  ('SAGEBRUSH CLUELESS', 106, 61),
#  ('CHITTY LOCK', 107, 62),
#  ('DIARY PANIC', 107, 62),
#  ('EFFECT GLADIATOR', 107, 62),
#  ('HANKY OCTOBER', 107, 62),
#  ('HATE HANDICAP', 107, 62),
#  ('INTENTIONS EMPIRE', 107, 62),
#  ('MONSTER SPARTACUS', 107, 62),
#  ('PARTY KNOCK', 107, 62),
#  ('UNDEFEATED DALMATIONS', 107, 62),
#  ('WANDA CHAMBER', 107, 62),
#  ('AUTUMN CROW', 108, 63),
#  ('GORGEOUS BINGO', 108, 63),
#  ('HANDICAP BOONDOCK', 108, 63),
#  ('LORD ARIZONA', 108, 63),
#  ('SWEETHEARTS SUSPECTS', 108, 63),
#  ('COMA HEAD', 109, 64),
#  ('HOUSE DYNAMITE', 109, 64),
#  ('PANTHER REDS', 109, 64),
#  ('PARK CITIZEN', 109, 64),
#  ('RUGRATS SHAKESPEARE', 109, 64),
#  ('SECRETS PARADISE', 109, 64),
#  ('WHALE BIKINI', 109, 64),
#  ('CELEBRITY HORN', 110, 65),
#  ('DRUMLINE CYCLONE', 110, 65),
#  ('HIGHBALL POTTER', 110, 65),
#  ('LEAGUE HELLFIGHTERS', 110, 65),
#  ('REMEMBER DIARY', 110, 65),
#  ('SAMURAI LION', 110, 65),
#  ('SEATTLE EXPECATIONS', 110, 65),
#  ('SNATCH SLIPPER', 110, 65),
#  ('TRAP GUYS', 110, 65),
#  ('FROGMEN BREAKING', 111, 66),
#  ('GROOVE FICTION', 111, 66),
#  ('SIEGE MADRE', 111, 66),
#  ('SUIT WALLS', 111, 66),
#  ('TIES HUNGER', 111, 66),
#  ('WIND PHANTOM', 111, 66),
#  ('WONDERLAND CHRISTMAS', 111, 66),
#  ('CAT CONEHEADS', 112, 67),
#  ('CONEHEADS SMOOCHY', 112, 67),
#  ('CONVERSATION DOWNHILL', 112, 67),
#  ('CROWDS TELEMARK', 112, 67),
#  ('CRUSADE HONEY', 112, 67),
#  ('FORRESTER COMANCHEROS', 112, 67),
#  ('JAWS HARRY', 112, 67),
#  ('QUILLS BULL', 112, 67),
#  ('SEABISCUIT PUNK', 112, 67),
#  ('SPY MILE', 112, 67),
#  ('STAGECOACH ARMAGEDDON', 112, 67),
#  ('WAIT CIDER', 112, 67),
#  ('WATERSHIP FRONTIER', 112, 67),
#  ('AMADEUS HOLY', 113, 68),
#  ('ATTACKS HATE', 113, 68),
#  ('BANGER PINOCCHIO', 113, 68),
#  ('DAY UNFAITHFUL', 113, 68),
#  ('LADYBUGS ARMAGEDDON', 113, 68),
#  ('LEGALLY SECRETARY', 113, 68),
#  ('SHEPHERD MIDSUMMER', 113, 68),
#  ('STATE WASTELAND', 113, 68),
#  ('ALABAMA DEVIL', 114, 69),
#  ('BLADE POLISH', 114, 69),
#  ('CARRIE BUNCH', 114, 69),
#  ('CHAINSAW UPTOWN', 114, 69),
#  ('CHASING FIGHT', 114, 69),
#  ('GILBERT PELICAN', 114, 69),
#  ('MARRIED GO', 114, 69),
#  ('PRIDE ALAMO', 114, 69),
#  ('SUGAR WONKA', 114, 69),
#  ('SUPERFLY TRIP', 114, 69),
#  ('CONNECTION MICROCOSMOS', 115, 70),
#  ('ELEMENT FREDDY', 115, 70),
#  ('GLORY TRACY', 115, 70),
#  ('OSCAR GOLD', 115, 70),
#  ('POTTER CONNECTICUT', 115, 70),
#  ('PRIX UNDEFEATED', 115, 70),
#  ('TROOPERS METAL', 115, 70),
#  ('DUCK RACER', 116, 71),
#  ('INSTINCT AIRPORT', 116, 71),
#  ('MADIGAN DORADO', 116, 71),
#  ('WORDS HUNTER', 116, 71),
#  ('AFFAIR PREJUDICE', 117, 72),
#  ('CHAMBER ITALIAN', 117, 72),
#  ('GRAFFITI LOVE', 117, 72),
#  ('MAGIC MALLRATS', 117, 72),
#  ('RESURRECTION SILVERADO', 117, 72),
#  ('BACKLASH UNDEFEATED', 118, 73),
#  ('FIDELITY DEVIL', 118, 73),
#  ('JAWBREAKER BROOKLYN', 118, 73),
#  ('ORIENT CLOSER', 118, 73),
#  ('OTHERS SOUP', 118, 73),
#  ('PATHS CONTROL', 118, 73),
#  ('PERSONAL LADYBUGS', 118, 73),
#  ('ROUGE SQUAD', 118, 73),
#  ('APOCALYPSE FLAMINGOS', 119, 74),
#  ('BUGSY SONG', 119, 74),
#  ('DUMBO LUST', 119, 74),
#  ('GAMES BOWFINGER', 119, 74),
#  ('IDENTITY LOVER', 119, 74),
#  ('STRANGERS GRAFFITI', 119, 74),
#  ('CALENDAR GUNFIGHT', 120, 75),
#  ('COMMAND DARLING', 120, 75),
#  ('DAZED PUNK', 120, 75),
#  ('DOLLS RAGE', 120, 75),
#  ('KARATE MOON', 120, 75),
#  ('LOCK REAR', 120, 75),
#  ('ORDER BETRAYED', 120, 75),
#  ('RAGE GAMES', 120, 75),
#  ('UNTOUCHABLES SUNRISE', 120, 75),
#  ('ARIZONA BANG', 121, 76),
#  ('BOOGIE AMELIE', 121, 76),
#  ('BRANNIGAN SUNRISE', 121, 76),
#  ('DANGEROUS UPTOWN', 121, 76),
#  ('HARRY IDAHO', 121, 76),
#  ('JUMANJI BLADE', 121, 76),
#  ('PARIS WEEKEND', 121, 76),
#  ('PURE RUNNER', 121, 76),
#  ('BEACH HEARTBREAKERS', 122, 77),
#  ('BETRAYED REAR', 122, 77),
#  ('CHICKEN HELLFIGHTERS', 122, 77),
#  ('CONFUSED CANDLES', 122, 77),
#  ('DECEIVER BETRAYED', 122, 77),
#  ('DOGMA FAMILY', 122, 77),
#  ('EXTRAORDINARY CONQUERER', 122, 77),
#  ('HOURS RAGE', 122, 77),
#  ('ILLUSION AMELIE', 122, 77),
#  ('MIGHTY LUCK', 122, 77),
#  ('VANILLA DAY', 122, 77),
#  ('BREAKFAST GOLDFINGER', 123, 78),
#  ('FLASH WARS', 123, 78),
#  ('INSECTS STONE', 123, 78),
#  ('MASK PEACH', 123, 78),
#  ('REEF SALUTE', 123, 78),
#  ('SWARM GOLD', 123, 78),
#  ('VANISHING ROCKY', 123, 78),
#  ('CHISUM BEHAVIOR', 124, 79),
#  ('CLONES PINOCCHIO', 124, 79),
#  ('JINGLE SAGEBRUSH', 124, 79),
#  ('SPEED SUIT', 124, 79),
#  ('BULL SHAWSHANK', 125, 80),
#  ('DONNIE ALLEY', 125, 80),
#  ('FISH OPUS', 125, 80),
#  ('GENTLEMEN STAGE', 125, 80),
#  ('HUNTER ALTER', 125, 80),
#  ('SAINTS BRIDE', 125, 80),
#  ('SHINING ROSES', 125, 80),
#  ('ALAMO VIDEOTAPE', 126, 81),
#  ('ELEPHANT TROJAN', 126, 81),
#  ('FREAKY POCUS', 126, 81),
#  ('MONTEZUMA COMMAND', 126, 81),
#  ('PAJAMA JAWBREAKER', 126, 81),
#  ('SINNERS ATLANTIS', 126, 81),
#  ('VAMPIRE WHALE', 126, 81),
#  ('WOMEN DORADO', 126, 81),
#  ('WONDERFUL DROP', 126, 81),
#  ('ARGONAUTS TOWN', 127, 82),
#  ('GUNFIGHTER MUSSOLINI', 127, 82),
#  ('MALTESE HOPE', 127, 82),
#  ('SEVEN SWARM', 127, 82),
#  ('SUBMARINE BED', 127, 82),
#  ('GALAXY SWEETHEARTS', 128, 83),
#  ('HOLES BRANNIGAN', 128, 83),
#  ('JEDI BENEATH', 128, 83),
#  ('NOTORIOUS REUNION', 128, 83),
#  ('PAPI NECKLACE', 128, 83),
#  ('USUAL UNTOUCHABLES', 128, 83),
#  ('WARS PLUTO', 128, 83),
#  ('AMERICAN CIRCUS', 129, 84),
#  ('BAREFOOT MANCHURIAN', 129, 84),
#  ('GOSFORD DONNIE', 129, 84),
#  ('MUSIC BOONDOCK', 129, 84),
#  ('OUTFIELD MASSACRE', 129, 84),
#  ('SLEEPING SUSPECTS', 129, 84),
#  ('UNFORGIVEN ZOOLANDER', 129, 84),
#  ('AFRICAN EGG', 130, 85),
#  ('DARKO DORADO', 130, 85),
#  ('FARGO GANDHI', 130, 85),
#  ('JASON TRAP', 130, 85),
#  ('MAJESTIC FLOATS', 130, 85),
#  ('STALLION SUNDANCE', 130, 85),
#  ('FANTASIA PARK', 131, 86),
#  ('FOREVER CANDIDATE', 131, 86),
#  ('ICE CROSSING', 131, 86),
#  ('NEMO CAMPUS', 131, 86),
#  ('OPEN AFRICAN', 131, 86),
#  ('CHOCOLATE DUCK', 132, 87),
#  ('DUDE BLINDNESS', 132, 87),
#  ('NECKLACE OUTBREAK', 132, 87),
#  ('PLATOON INSTINCT', 132, 87),
#  ('SKY MIRACLE', 132, 87),
#  ('STREAK RIDGEMONT', 132, 87),
#  ('TRAINSPOTTING STRANGERS', 132, 87),
#  ('VOLUME HOUSE', 132, 87),
#  ('BUCKET BROTHERHOOD', 133, 88),
#  ('CURTAIN VIDEOTAPE', 133, 88),
#  ('DRAGONFLY STRANGERS', 133, 88),
#  ('FREEDOM CLEOPATRA', 133, 88),
#  ('MALLRATS UNITED', 133, 88),
#  ('JUNGLE CLOSER', 134, 89),
#  ('PITTSBURGH HUNCHBACK', 134, 89),
#  ('ROBBERY BRIGHT', 134, 89),
#  ('SPLENDOR PATTON', 134, 89),
#  ('WEEKEND PERSONAL', 134, 89),
#  ('CANDLES GRAPES', 135, 90),
#  ('DREAM PICKUP', 135, 90),
#  ('GREASE YOUTH', 135, 90),
#  ('INDIAN LOVE', 135, 90),
#  ('JAPANESE RUN', 135, 90),
#  ('MONEY HAROLD', 135, 90),
#  ('SIERRA DIVIDE', 135, 90),
#  ('SUNRISE LEAGUE', 135, 90),
#  ('THIEF PELICAN', 135, 90),
#  ('WALLS ARTIST', 135, 90),
#  ('ALASKA PHANTOM', 136, 91),
#  ('BRINGING HYSTERICAL', 136, 91),
#  ('CRAZY HOME', 136, 91),
#  ('HOLLOW JEOPARDY', 136, 91),
#  ('MAKER GABLES', 136, 91),
#  ('PIANIST OUTFIELD', 136, 91),
#  ('REAP UNFAITHFUL', 136, 91),
#  ('SQUAD FISH', 136, 91),
#  ('TOWN ARK', 136, 91),
#  ('ARSENIC INDEPENDENCE', 137, 92),
#  ('GRIT CLOCKWORK', 137, 92),
#  ('LIFE TWISTED', 137, 92),
#  ('LOSE INCH', 137, 92),
#  ('PHILADELPHIA WIFE', 137, 92),
#  ('POLLOCK DELIVERANCE', 137, 92),
#  ('SCORPION APOLLO', 137, 92),
#  ('SLEEPY JAPANESE', 137, 92),
#  ('WILLOW TRACY', 137, 92),
#  ('EXPECATIONS NATURAL', 138, 93),
#  ('LIBERTY MAGNIFICENT', 138, 93),
#  ('MAIDEN HOME', 138, 93),
#  ('POCUS PULP', 138, 93),
#  ('SPINAL ROCKY', 138, 93),
#  ('SPIRITED CASUALTIES', 138, 93),
#  ('CLYDE THEORY', 139, 94),
#  ('CREATURES SHAKESPEARE', 139, 94),
#  ('DORADO NOTTING', 139, 94),
#  ('GROUNDHOG UNCUT', 139, 94),
#  ('HOPE TOOTSIE', 139, 94),
#  ('HORROR REIGN', 139, 94),
#  ('SHRUNK DIVINE', 139, 94),
#  ('STRANGER STRANGERS', 139, 94),
#  ('TRAFFIC HOBBIT', 139, 94),
#  ('VOICE PEACH', 139, 94),
#  ('WORKER TARZAN', 139, 94),
#  ('EAGLES PANKY', 140, 95),
#  ('GRACELAND DYNAMITE', 140, 95),
#  ('LIAISONS SWEET', 140, 95),
#  ('LOATHING LEGALLY', 140, 95),
#  ('STEERS ARMAGEDDON', 140, 95),
#  ('DISCIPLE MOTHER', 141, 96),
#  ('DYNAMITE TARZAN', 141, 96),
#  ('HOCUS FRIDA', 141, 96),
#  ('HOMICIDE PEACH', 141, 96),
#  ('KISSING DOLLS', 141, 96),
#  ('SPICE SORORITY', 141, 96),
#  ('SUN CONFESSIONS', 141, 96),
#  ('BIKINI BORROWERS', 142, 97),
#  ('CHILL LUCK', 142, 97),
#  ('FERRIS MOTHER', 142, 97),
#  ('MILLION ACE', 142, 97),
#  ('TOMORROW HUSTLER', 142, 97),
#  ('TRACY CIDER', 142, 97),
#  ('VANISHED GARDEN', 142, 97),
#  ('CINCINATTI WHISPERER', 143, 98),
#  ('CLOCKWORK PARADISE', 143, 98),
#  ('CROOKED FROGMEN', 143, 98),
#  ('DETECTIVE VISION', 143, 98),
#  ('ENCINO ELF', 143, 98),
#  ('SOUTH WAIT', 143, 98),
#  ('STEEL SANTA', 143, 98),
#  ('DANCING FEVER', 144, 99),
#  ('FACTORY DRAGON', 144, 99),
#  ('LAMBS CINCINATTI', 144, 99),
#  ('PACIFIC AMISTAD', 144, 99),
#  ('PRESIDENT BANG', 144, 99),
#  ('STRICTLY SCARFACE', 144, 99),
#  ('TOWERS HURRICANE', 144, 99),
#  ('VIRTUAL SPOILERS', 144, 99),
#  ('FLOATS GARDEN', 145, 100),
#  ('NUTS TIES', 145, 100),
#  ('PAYCHECK WAIT', 145, 100),
#  ('ROCKY WAR', 145, 100),
#  ('RUN PACIFIC', 145, 100),
#  ('VACATION BOONDOCK', 145, 100),
#  ('VIDEOTAPE ARSENIC', 145, 100),
#  ('CHAPLIN LICENSE', 146, 101),
#  ('COWBOY DOOM', 146, 101),
#  ('HALF OUTFIELD', 146, 101),
#  ('HAMLET WISDOM', 146, 101),
#  ('MOURNING PURPLE', 146, 101),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 147, 102),
#  ('DIRTY ACE', 147, 102),
#  ('LIES TREATMENT', 147, 102),
#  ('MADISON TRAP', 147, 102),
#  ('MENAGERIE RUSHMORE', 147, 102),
#  ('RACER EGG', 147, 102),
#  ('RANGE MOONWALKER', 147, 102),
#  ('SCISSORHANDS SLUMS', 147, 102),
#  ('SLUMS DUCK', 147, 102),
#  ('ARMY FLINTSTONES', 148, 103),
#  ('BLANKET BEVERLY', 148, 103),
#  ('EASY GLADIATOR', 148, 103),
#  ('FIREBALL PHILADELPHIA', 148, 103),
#  ('FLINTSTONES HAPPINESS', 148, 103),
#  ('OUTLAW HANKY', 148, 103),
#  ('TELEGRAPH VOYAGE', 148, 103),
#  ('COLOR PHILADELPHIA', 149, 104),
#  ('HOLOCAUST HIGHBALL', 149, 104),
#  ('MINDS TRUMAN', 149, 104),
#  ('NIGHTMARE CHILL', 149, 104),
#  ('RIVER OUTLAW', 149, 104),
#  ('SPIRIT FLINTSTONES', 149, 104),
#  ('ALI FOREVER', 150, 105),
#  ('BINGO TALENTED', 150, 105),
#  ('CHRISTMAS MOONSHINE', 150, 105),
#  ('CLEOPATRA DEVIL', 150, 105),
#  ('GRINCH MASSAGE', 150, 105),
#  ('HYSTERICAL GRAIL', 150, 105),
#  ('RUSHMORE MERMAID', 150, 105),
#  ('SATURDAY LAMBS', 150, 105),
#  ('BEETHOVEN EXORCIST', 151, 106),
#  ('CAROL TEXAS', 151, 106),
#  ('HUNCHBACK IMPOSSIBLE', 151, 106),
#  ('MASKED BUBBLE', 151, 106),
#  ('SCHOOL JACKET', 151, 106),
#  ('SPOILERS HELLFIGHTERS', 151, 106),
#  ('STRAIGHT HOURS', 151, 106),
#  ('CENTER DINOSAUR', 152, 107),
#  ('ELIZABETH SHANE', 152, 107),
#  ('LUCK OPUS', 152, 107),
#  ('SISTER FREDDY', 152, 107),
#  ('TELEMARK HEARTBREAKERS', 152, 107),
#  ('TOURIST PELICAN', 152, 107),
#  ('TUXEDO MILE', 152, 107),
#  ('TWISTED PIRATES', 152, 107),
#  ('WAGON JAWS', 152, 107),
#  ('APOLLO TEEN', 153, 108),
#  ('BABY HALL', 153, 108),
#  ('CROSSROADS CASUALTIES', 153, 108),
#  ('EDGE KISSING', 153, 108),
#  ('GOLDMINE TYCOON', 153, 108),
#  ('LEATHERNECKS DWARFS', 153, 108),
#  ('RIGHT CRANES', 153, 108),
#  ('ROLLERCOASTER BRINGING', 153, 108),
#  ('RULES HUMAN', 153, 108),
#  ('DOUBTFIRE LABYRINTH', 154, 109),
#  ('DURHAM PANKY', 154, 109),
#  ('GOLD RIVER', 154, 109),
#  ('RAGING AIRPLANE', 154, 109),
#  ('SANTA PARIS', 154, 109),
#  ('SASSY PACKER', 154, 109),
#  ('SHREK LICENSE', 154, 109),
#  ('ELF MURDER', 155, 110),
#  ('FAMILY SWEET', 155, 110),
#  ('GRAPES FURY', 155, 110),
#  ('LOLITA WORLD', 155, 110),
#  ('PSYCHO SHRUNK', 155, 110),
#  ('TADPOLE PARK', 155, 110),
#  ('FINDING ANACONDA', 156, 111),
#  ('GRADUATE LORD', 156, 111),
#  ('OPERATION OPERATION', 156, 111),
#  ('SLIPPER FIDELITY', 156, 111),
#  ('HOBBIT ALIEN', 157, 112),
#  ('INDEPENDENCE HOTEL', 157, 112),
#  ('MULHOLLAND BEAST', 157, 112),
#  ('PAST SUICIDES', 157, 112),
#  ('TOOTSIE PILOT', 157, 112),
#  ('VOLCANO TEXAS', 157, 112),
#  ('ENOUGH RAGING', 158, 113),
#  ('FEVER EMPIRE', 158, 113),
#  ('FOOL MOCKINGBIRD', 158, 113),
#  ('MONTEREY LABYRINTH', 158, 113),
#  ('ROAD ROXANNE', 158, 113),
#  ('SECRETARY ROUGE', 158, 113),
#  ('DRIVER ANNIE', 159, 114),
#  ('FRANKENSTEIN STRANGER', 159, 114),
#  ('MALKOVICH PET', 159, 114),
#  ('NEWSIES STORY', 159, 114),
#  ('POSEIDON FOREVER', 159, 114),
#  ('WEST LION', 159, 114),
#  ('BEAR GRACELAND', 160, 115),
#  ('IGBY MAKER', 160, 115),
#  ('MULAN MOON', 160, 115),
#  ('MUMMY CREATURES', 160, 115),
#  ('PEACH INNOCENT', 160, 115),
#  ('STOCK GLASS', 160, 115),
#  ('BROOKLYN DESERT', 161, 116),
#  ('DADDY PITTSBURGH', 161, 116),
#  ('GABLES METROPOLIS', 161, 116),
#  ('KILLER INNOCENT', 161, 116),
#  ('MASSAGE IMAGE', 161, 116),
#  ('METAL ARMAGEDDON', 161, 116),
#  ('NEIGHBORS CHARADE', 161, 116),
#  ('OLEANDER CLUE', 161, 116),
#  ('WASH HEAVENLY', 161, 116),
#  ('BADMAN DAWN', 162, 117),
#  ('BIRCH ANTITRUST', 162, 117),
#  ('LOVERBOY ATTACKS', 162, 117),
#  ('MIRACLE VIRTUAL', 162, 117),
#  ('ROSES TREASURE', 162, 117),
#  ('BIRD INDEPENDENCE', 163, 118),
#  ('CASPER DRAGONFLY', 163, 118),
#  ('EVERYONE CRAFT', 163, 118),
#  ('GILMORE BOILED', 163, 118),
#  ('KISS GLORY', 163, 118),
#  ('QUEEN LUKE', 163, 118),
#  ('STORY SIDE', 163, 118),
#  ('CLERKS ANGELS', 164, 119),
#  ('MISSION ZOOLANDER', 164, 119),
#  ('UNITED PILOT', 164, 119),
#  ('VIRGINIAN PLUTO', 164, 119),
#  ('CITIZEN SHREK', 165, 120),
#  ('DARLING BREAKING', 165, 120),
#  ('MASSACRE USUAL', 165, 120),
#  ('SONG HEDWIG', 165, 120),
#  ('SPEAKEASY DATE', 165, 120),
#  ('CONTACT ANONYMOUS', 166, 121),
#  ('GREEDY ROOTS', 166, 121),
#  ('MINE TITANS', 166, 121),
#  ('MOTIONS DETAILS', 166, 121),
#  ('MURDER ANTITRUST', 166, 121),
#  ('CAMPUS REMEMBER', 167, 122),
#  ('ESCAPE METROPOLIS', 167, 122),
#  ('EXORCIST STING', 167, 122),
#  ('INCH JET', 167, 122),
#  ('LESSON CLEOPATRA', 167, 122),
#  ('REQUIEM TYCOON', 167, 122),
#  ('SHOW LORD', 167, 122),
#  ('ANTITRUST TOMATOES', 168, 123),
#  ('DYING MAKER', 168, 123),
#  ('HAROLD FRENCH', 168, 123),
#  ('TRANSLATION SUMMER', 168, 123),
#  ('AGENT TRUMAN', 169, 124),
#  ('BREAKING HOME', 169, 124),
#  ('HEDWIG ALTER', 169, 124),
#  ('KENTUCKIAN GIANT', 169, 124),
#  ('OUTBREAK DIVINE', 169, 124),
#  ('SOUP WISDOM', 169, 124),
#  ('ARTIST COLDBLOODED', 170, 125),
#  ('ATLANTIS CAUSE', 170, 125),
#  ('DRAGON SQUAD', 170, 125),
#  ('TRADING PINOCCHIO', 170, 125),
#  ('DUFFEL APOCALYPSE', 171, 126),
#  ('JERICHO MULAN', 171, 126),
#  ('KRAMER CHOCOLATE', 171, 126),
#  ('MAGNOLIA FORRESTER', 171, 126),
#  ('MOONSHINE CABIN', 171, 126),
#  ('ROXANNE REBEL', 171, 126),
#  ('TRAMP OTHERS', 171, 126),
#  ('WORLD LEATHERNECKS', 171, 126),
#  ('CONNECTICUT TRAMP', 172, 127),
#  ('CREEPERS KANE', 172, 127),
#  ('EYES DRIVING', 172, 127),
#  ('IDAHO LOVE', 172, 127),
#  ('JERK PAYCHECK', 172, 127),
#  ('NORTHWEST POLISH', 172, 127),
#  ('TIGHTS DAWN', 172, 127),
#  ('UNCUT SUICIDES', 172, 127),
#  ('BALLROOM MOCKINGBIRD', 173, 128),
#  ('CONQUERER NUTS', 173, 128),
#  ('FIRE WOLVES', 173, 128),
#  ('GLADIATOR WESTWARD', 173, 128),
#  ('PIZZA JUMANJI', 173, 128),
#  ('TALENTED HOMICIDE', 173, 128),
#  ('VELVET TERMINATOR', 173, 128),
#  ('EVOLUTION ALTER', 174, 129),
#  ('ITALIAN AFRICAN', 174, 129),
#  ('JADE BUNCH', 174, 129),
#  ('LIGHTS DEER', 174, 129),
#  ('UPRISING UPTOWN', 174, 129),
#  ('VIETNAM SMOOCHY', 174, 129),
#  ('BEAUTY GREASE', 175, 130),
#  ('DRIVING POLISH', 175, 130),
#  ('LAWRENCE LOVE', 175, 130),
#  ('MODEL FISH', 175, 130),
#  ('PATTON INTERVIEW', 175, 130),
#  ('SPLASH GUMP', 175, 130),
#  ('BRAVEHEART HUMAN', 176, 131),
#  ('CAPER MOTIONS', 176, 131),
#  ('CYCLONE FAMILY', 176, 131),
#  ('DRACULA CRYSTAL', 176, 131),
#  ('ENTRAPMENT SATISFACTION', 176, 131),
#  ('GATHERING CALENDAR', 176, 131),
#  ('GREEK EVERYONE', 176, 131),
#  ('HOOSIERS BIRDCAGE', 176, 131),
#  ('SWEDEN SHINING', 176, 131),
#  ('WRATH MILE', 176, 131),
#  ('DOUBLE WRATH', 177, 132),
#  ('DOZEN LION', 177, 132),
#  ('EMPIRE MALKOVICH', 177, 132),
#  ('MANCHURIAN CURTAIN', 177, 132),
#  ('QUEST MUSSOLINI', 177, 132),
#  ('RIDER CADDYSHACK', 177, 132),
#  ('DROP WATERFRONT', 178, 133),
#  ('EXPRESS LONELY', 178, 133),
#  ('FURY MURDER', 178, 133),
#  ('IMAGE PRINCESS', 178, 133),
#  ('INNOCENT USUAL', 178, 133),
#  ('MADNESS ATTACKS', 178, 133),
#  ('NAME DETECTIVE', 178, 133),
#  ('ROCKETEER MOTHER', 178, 133),
#  ('WARDROBE PHANTOM', 178, 133),
#  ('WRONG BEHAVIOR', 178, 133),
#  ('ANONYMOUS HUMAN', 179, 134),
#  ('BORN SPINAL', 179, 134),
#  ('CASUALTIES ENCINO', 179, 134),
#  ('CAUSE DATE', 179, 134),
#  ('FLIGHT LIES', 179, 134),
#  ('KICK SAVANNAH', 179, 134),
#  ('POTLUCK MIXED', 179, 134),
#  ('REDEMPTION COMFORTS', 179, 134),
#  ('SLACKER LIAISONS', 179, 134),
#  ('TEXAS WATCH', 179, 134),
#  ('TORQUE BOUND', 179, 134),
#  ('VIRGIN DAISY', 179, 134),
#  ('YOUTH KICK', 179, 134),
#  ('ALLEY EVOLUTION', 180, 135),
#  ('CONFIDENTIAL INTERVIEW', 180, 135),
#  ('IMPACT ALADDIN', 180, 135),
#  ('MIXED DOORS', 180, 135),
#  ('MUSSOLINI SPOILERS', 180, 135),
#  ('NASH CHOCOLAT', 180, 135),
#  ('SOMETHING DUCK', 180, 135),
#  ('ANALYZE HOOSIERS', 181, 136),
#  ('HAUNTING PIANIST', 181, 136),
#  ('HOTEL HAPPINESS', 181, 136),
#  ('INTRIGUE WORST', 181, 136),
#  ('JACKET FRISCO', 181, 136),
#  ('LAWLESS VISION', 181, 136),
#  ('LOVE SUICIDES', 181, 136),
#  ('RUNAWAY TENENBAUMS', 181, 136),
#  ('STAR OPERATION', 181, 136),
#  ('WILD APOLLO', 181, 136),
#  ('BAKED CLEOPATRA', 182, 137),
#  ('MONSOON CAUSE', 182, 137),
#  ('RECORDS ZORRO', 182, 137),
#  ('REDS POCUS', 182, 137),
#  ('SATURN NAME', 182, 137),
#  ('SEARCHERS WAIT', 182, 137),
#  ('CATCH AMISTAD', 183, 138),
#  ('FRONTIER CABIN', 183, 138),
#  ('SCALAWAG DUCK', 183, 138),
#  ('WIFE TURN', 183, 138),
#  ('YOUNG LANGUAGE', 183, 138),
#  ('CONSPIRACY SPIRIT', 184, 139),
#  ('CRYSTAL BREAKING', 184, 139),
#  ('KING EVOLUTION', 184, 139),
#  ('MOONWALKER FOOL', 184, 139),
#  ('SMOOCHY CONTROL', 184, 139),
#  ('SONS INTERVIEW', 184, 139),
#  ('SORORITY QUEEN', 184, 139),
#  ('THEORY MERMAID', 184, 139),
#  ('CHICAGO NORTH', 185, 140),
#  ('CONTROL ANTHEM', 185, 140),
#  ('DARN FORRESTER', 185, 140),
#  ('GANGS PRIDE', 185, 140),
#  ('HOME PITY', 185, 140),
#  ('MUSCLE BRIGHT', 185, 140),
#  ('POND SEATTLE', 185, 140),
#  ('SOLDIERS EVOLUTION', 185, 140),
#  ('SWEET BROTHERHOOD', 185, 140),
#  ('WORST BANGER', 185, 140)]

# %% [markdown]
# ##### 2. Rank films by length within the rating category (filter out the rows with nulls or zeros in length column). In your output, only select the columns title, length, rating and rank.

# %%
# %%sql
# select title, length, rating, dense_rank() over (partition by rating order by length desc) as 'rank'
# from sakila.film
# where length>0 and length is not null;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 1000 rows affected.
# [('CONTROL ANTHEM', 185, 'G', 1),
#  ('DARN FORRESTER', 185, 'G', 1),
#  ('MUSCLE BRIGHT', 185, 'G', 1),
#  ('MOONWALKER FOOL', 184, 'G', 2),
#  ('CATCH AMISTAD', 183, 'G', 3),
#  ('YOUNG LANGUAGE', 183, 'G', 3),
#  ('BAKED CLEOPATRA', 182, 'G', 4),
#  ('INTRIGUE WORST', 181, 'G', 5),
#  ('LAWLESS VISION', 181, 'G', 5),
#  ('MUSSOLINI SPOILERS', 180, 'G', 6),
#  ('CASUALTIES ENCINO', 179, 'G', 7),
#  ('POTLUCK MIXED', 179, 'G', 7),
#  ('TORQUE BOUND', 179, 'G', 7),
#  ('WARDROBE PHANTOM', 178, 'G', 8),
#  ('EMPIRE MALKOVICH', 177, 'G', 9),
#  ('CAPER MOTIONS', 176, 'G', 10),
#  ('DRACULA CRYSTAL', 176, 'G', 10),
#  ('HOOSIERS BIRDCAGE', 176, 'G', 10),
#  ('BEAUTY GREASE', 175, 'G', 11),
#  ('ITALIAN AFRICAN', 174, 'G', 12),
#  ('BALLROOM MOCKINGBIRD', 173, 'G', 13),
#  ('CONQUERER NUTS', 173, 'G', 13),
#  ('DUFFEL APOCALYPSE', 171, 'G', 14),
#  ('ATLANTIS CAUSE', 170, 'G', 15),
#  ('EXORCIST STING', 167, 'G', 16),
#  ('CITIZEN SHREK', 165, 'G', 17),
#  ('CLERKS ANGELS', 164, 'G', 18),
#  ('BIRD INDEPENDENCE', 163, 'G', 19),
#  ('DADDY PITTSBURGH', 161, 'G', 20),
#  ('MULAN MOON', 160, 'G', 21),
#  ('MALKOVICH PET', 159, 'G', 22),
#  ('NEWSIES STORY', 159, 'G', 22),
#  ('WEST LION', 159, 'G', 22),
#  ('MONTEREY LABYRINTH', 158, 'G', 23),
#  ('GRADUATE LORD', 156, 'G', 24),
#  ('OPERATION OPERATION', 156, 'G', 24),
#  ('GRAPES FURY', 155, 'G', 25),
#  ('SASSY PACKER', 154, 'G', 26),
#  ('CROSSROADS CASUALTIES', 153, 'G', 27),
#  ('SPOILERS HELLFIGHTERS', 151, 'G', 28),
#  ('SATURDAY LAMBS', 150, 'G', 29),
#  ('COLOR PHILADELPHIA', 149, 'G', 30),
#  ('BLANKET BEVERLY', 148, 'G', 31),
#  ('EASY GLADIATOR', 148, 'G', 31),
#  ('MENAGERIE RUSHMORE', 147, 'G', 32),
#  ('SCISSORHANDS SLUMS', 147, 'G', 32),
#  ('DANCING FEVER', 144, 'G', 33),
#  ('PACIFIC AMISTAD', 144, 'G', 33),
#  ('ENCINO ELF', 143, 'G', 34),
#  ('TRACY CIDER', 142, 'G', 35),
#  ('HOCUS FRIDA', 141, 'G', 36),
#  ('STRANGER STRANGERS', 139, 'G', 37),
#  ('TRAFFIC HOBBIT', 139, 'G', 37),
#  ('LIBERTY MAGNIFICENT', 138, 'G', 38),
#  ('GREASE YOUTH', 135, 'G', 39),
#  ('JAPANESE RUN', 135, 'G', 39),
#  ('DUDE BLINDNESS', 132, 'G', 40),
#  ('FANTASIA PARK', 131, 'G', 41),
#  ('AFRICAN EGG', 130, 'G', 42),
#  ('FARGO GANDHI', 130, 'G', 42),
#  ('BAREFOOT MANCHURIAN', 129, 'G', 43),
#  ('GOSFORD DONNIE', 129, 'G', 43),
#  ('WARS PLUTO', 128, 'G', 44),
#  ('ALAMO VIDEOTAPE', 126, 'G', 45),
#  ('SAINTS BRIDE', 125, 'G', 46),
#  ('SHINING ROSES', 125, 'G', 46),
#  ('CHISUM BEHAVIOR', 124, 'G', 47),
#  ('BREAKFAST GOLDFINGER', 123, 'G', 48),
#  ('BEACH HEARTBREAKERS', 122, 'G', 49),
#  ('DOGMA FAMILY', 122, 'G', 49),
#  ('EXTRAORDINARY CONQUERER', 122, 'G', 49),
#  ('JUMANJI BLADE', 121, 'G', 50),
#  ('DAZED PUNK', 120, 'G', 51),
#  ('BUGSY SONG', 119, 'G', 52),
#  ('FIDELITY DEVIL', 118, 'G', 53),
#  ('AFFAIR PREJUDICE', 117, 'G', 54),
#  ('CONNECTION MICROCOSMOS', 115, 'G', 55),
#  ('GILBERT PELICAN', 114, 'G', 56),
#  ('MARRIED GO', 114, 'G', 56),
#  ('DAY UNFAITHFUL', 113, 'G', 57),
#  ('CAT CONEHEADS', 112, 'G', 58),
#  ('JAWS HARRY', 112, 'G', 58),
#  ('WATERSHIP FRONTIER', 112, 'G', 58),
#  ('DRUMLINE CYCLONE', 110, 'G', 59),
#  ('SAMURAI LION', 110, 'G', 59),
#  ('TRAP GUYS', 110, 'G', 59),
#  ('SECRETS PARADISE', 109, 'G', 60),
#  ('AUTUMN CROW', 108, 'G', 61),
#  ('SWEETHEARTS SUSPECTS', 108, 'G', 61),
#  ('CHITTY LOCK', 107, 'G', 62),
#  ('DIARY PANIC', 107, 'G', 62),
#  ('SAGEBRUSH CLUELESS', 106, 'G', 63),
#  ('HUNGER ROOF', 105, 'G', 64),
#  ('MOB DUFFEL', 105, 'G', 64),
#  ('FIREHOUSE VIETNAM', 103, 'G', 65),
#  ('GLASS DYING', 103, 'G', 65),
#  ('HEAVYWEIGHTS BEAST', 102, 'G', 66),
#  ('PANIC CLUB', 102, 'G', 66),
#  ('ROCK INSTINCT', 102, 'G', 66),
#  ('DWARFS ALTER', 101, 'G', 67),
#  ('FLATLINERS KILLER', 100, 'G', 68),
#  ('GUN BONNIE', 100, 'G', 68),
#  ('HAPPINESS UNITED', 100, 'G', 68),
#  ('HYDE DOCTOR', 100, 'G', 68),
#  ('ARMAGEDDON LOST', 99, 'G', 69),
#  ('STONE FIRE', 94, 'G', 70),
#  ('GOLDFINGER SENSIBILITY', 93, 'G', 71),
#  ('HILLS NEIGHBORS', 93, 'G', 71),
#  ('PANKY SUBMARINE', 93, 'G', 71),
#  ('SUICIDES SILENCE', 93, 'G', 71),
#  ('TRUMAN CRAZY', 92, 'G', 72),
#  ('BUTTERFLY CHOCOLAT', 89, 'G', 73),
#  ('PULP BEVERLY', 89, 'G', 73),
#  ('CHEAPER CLYDE', 87, 'G', 74),
#  ('ANNIE IDENTITY', 86, 'G', 75),
#  ('MIDNIGHT WESTWARD', 86, 'G', 75),
#  ('AMISTAD MIDSUMMER', 85, 'G', 76),
#  ('CASABLANCA SUPER', 85, 'G', 76),
#  ('GHOST GROUNDHOG', 85, 'G', 76),
#  ('DAISY MENAGERIE', 84, 'G', 77),
#  ('WARLOCK WEREWOLF', 83, 'G', 78),
#  ('TYCOON GATHERING', 82, 'G', 79),
#  ('CLASH FREDDY', 81, 'G', 80),
#  ('DESPERATE TRAINSPOTTING', 81, 'G', 80),
#  ('GARDEN ISLAND', 80, 'G', 81),
#  ('MEET CHOCOLATE', 80, 'G', 81),
#  ('TURN STAR', 80, 'G', 81),
#  ('WAR NOTTING', 80, 'G', 81),
#  ('SPIKING ELEMENT', 79, 'G', 82),
#  ('WEREWOLF LOLA', 79, 'G', 82),
#  ('PICKUP DRIVING', 77, 'G', 83),
#  ('LOVER TRUMAN', 75, 'G', 84),
#  ('SATISFACTION CONFIDENTIAL', 75, 'G', 84),
#  ('ANGELS LIFE', 74, 'G', 85),
#  ('TEEN APOLLO', 74, 'G', 85),
#  ('REBEL AIRPORT', 73, 'G', 86),
#  ('VALLEY PACKER', 73, 'G', 86),
#  ('WAKE JAWS', 73, 'G', 86),
#  ('BLOOD ARGONAUTS', 71, 'G', 87),
#  ('COLDBLOODED DARLING', 70, 'G', 88),
#  ('CRUELTY UNFORGIVEN', 69, 'G', 89),
#  ('TIMBERLAND SKY', 69, 'G', 89),
#  ('LONELY ELEPHANT', 67, 'G', 90),
#  ('EVE RESURRECTION', 66, 'G', 91),
#  ('BARBARELLA STREETCAR', 65, 'G', 92),
#  ('NOVOCAINE FLIGHT', 64, 'G', 93),
#  ('SLEEPLESS MONSOON', 64, 'G', 93),
#  ('BONNIE HOLOCAUST', 63, 'G', 94),
#  ('BORROWERS BEDAZZLED', 63, 'G', 94),
#  ('BUNCH MINDS', 63, 'G', 94),
#  ('HANGING DEEP', 62, 'G', 95),
#  ('SNOWMAN ROLLERCOASTER', 62, 'G', 95),
#  ('UNBREAKABLE KARATE', 62, 'G', 95),
#  ('BIRDS PERDITION', 61, 'G', 96),
#  ('BULWORTH COMMANDMENTS', 61, 'G', 96),
#  ('WATERFRONT DELIVERANCE', 61, 'G', 96),
#  ('SMILE EARRING', 60, 'G', 97),
#  ('HEARTBREAKERS BRIGHT', 59, 'G', 98),
#  ('MINORITY KISS', 59, 'G', 98),
#  ('RINGS HEARTBREAKERS', 58, 'G', 99),
#  ('DOCTOR GRAIL', 57, 'G', 100),
#  ('MOSQUITO ARMAGEDDON', 57, 'G', 100),
#  ('NOON PAPI', 57, 'G', 100),
#  ('BRIDE INTRIGUE', 56, 'G', 101),
#  ('DESTINY SATURDAY', 56, 'G', 101),
#  ('KILL BROTHERHOOD', 54, 'G', 102),
#  ('PRIMARY GLASS', 53, 'G', 103),
#  ('SUMMER SCARFACE', 53, 'G', 103),
#  ('HARPER DYING', 52, 'G', 104),
#  ('LUST LOCK', 52, 'G', 104),
#  ('SIDE ARK', 52, 'G', 104),
#  ('EXCITEMENT EVE', 51, 'G', 105),
#  ('BLUES INSTINCT', 50, 'G', 106),
#  ('HOOK CHARIOTS', 49, 'G', 107),
#  ('ACE GOLDFINGER', 48, 'G', 108),
#  ('MIDSUMMER GROUNDHOG', 48, 'G', 108),
#  ('DIVORCE SHINING', 47, 'G', 109),
#  ('DOWNHILL ENOUGH', 47, 'G', 109),
#  ('WORST BANGER', 185, 'PG', 1),
#  ('MONSOON CAUSE', 182, 'PG', 2),
#  ('RECORDS ZORRO', 182, 'PG', 2),
#  ('STAR OPERATION', 181, 'PG', 3),
#  ('BORN SPINAL', 179, 'PG', 4),
#  ('MANCHURIAN CURTAIN', 177, 'PG', 5),
#  ('RIDER CADDYSHACK', 177, 'PG', 5),
#  ('CYCLONE FAMILY', 176, 'PG', 6),
#  ('GREEK EVERYONE', 176, 'PG', 6),
#  ('SWEDEN SHINING', 176, 'PG', 6),
#  ('PATTON INTERVIEW', 175, 'PG', 7),
#  ('SPLASH GUMP', 175, 'PG', 7),
#  ('GLADIATOR WESTWARD', 173, 'PG', 8),
#  ('TALENTED HOMICIDE', 173, 'PG', 8),
#  ('NORTHWEST POLISH', 172, 'PG', 9),
#  ('TRAMP OTHERS', 171, 'PG', 10),
#  ('TRADING PINOCCHIO', 170, 'PG', 11),
#  ('AGENT TRUMAN', 169, 'PG', 12),
#  ('KENTUCKIAN GIANT', 169, 'PG', 12),
#  ('DYING MAKER', 168, 'PG', 13),
#  ('MOTIONS DETAILS', 166, 'PG', 14),
#  ('MURDER ANTITRUST', 166, 'PG', 14),
#  ('EVERYONE CRAFT', 163, 'PG', 15),
#  ('QUEEN LUKE', 163, 'PG', 15),
#  ('BIRCH ANTITRUST', 162, 'PG', 16),
#  ('GABLES METROPOLIS', 161, 'PG', 17),
#  ('MASSAGE IMAGE', 161, 'PG', 17),
#  ('OLEANDER CLUE', 161, 'PG', 17),
#  ('STOCK GLASS', 160, 'PG', 18),
#  ('FOOL MOCKINGBIRD', 158, 'PG', 19),
#  ('SECRETARY ROUGE', 158, 'PG', 19),
#  ('MULHOLLAND BEAST', 157, 'PG', 20),
#  ('TOOTSIE PILOT', 157, 'PG', 20),
#  ('TADPOLE PARK', 155, 'PG', 21),
#  ('SANTA PARIS', 154, 'PG', 22),
#  ('CENTER DINOSAUR', 152, 'PG', 23),
#  ('TWISTED PIRATES', 152, 'PG', 23),
#  ('WAGON JAWS', 152, 'PG', 23),
#  ('CAROL TEXAS', 151, 'PG', 24),
#  ('ALI FOREVER', 150, 'PG', 25),
#  ('HYSTERICAL GRAIL', 150, 'PG', 25),
#  ('NIGHTMARE CHILL', 149, 'PG', 26),
#  ('FIREBALL PHILADELPHIA', 148, 'PG', 27),
#  ('TELEGRAPH VOYAGE', 148, 'PG', 27),
#  ('RANGE MOONWALKER', 147, 'PG', 28),
#  ('SLUMS DUCK', 147, 'PG', 28),
#  ('COWBOY DOOM', 146, 'PG', 29),
#  ('MOURNING PURPLE', 146, 'PG', 29),
#  ('PRESIDENT BANG', 144, 'PG', 30),
#  ('CHILL LUCK', 142, 'PG', 31),
#  ('FERRIS MOTHER', 142, 'PG', 31),
#  ('DISCIPLE MOTHER', 141, 'PG', 32),
#  ('LIAISONS SWEET', 140, 'PG', 33),
#  ('STEERS ARMAGEDDON', 140, 'PG', 33),
#  ('MAIDEN HOME', 138, 'PG', 34),
#  ('ARSENIC INDEPENDENCE', 137, 'PG', 35),
#  ('GRIT CLOCKWORK', 137, 'PG', 35),
#  ('POLLOCK DELIVERANCE', 137, 'PG', 35),
#  ('SLEEPY JAPANESE', 137, 'PG', 35),
#  ('ALASKA PHANTOM', 136, 'PG', 36),
#  ('BRINGING HYSTERICAL', 136, 'PG', 36),
#  ('CRAZY HOME', 136, 'PG', 36),
#  ('SQUAD FISH', 136, 'PG', 36),
#  ('DREAM PICKUP', 135, 'PG', 37),
#  ('MONEY HAROLD', 135, 'PG', 37),
#  ('WALLS ARTIST', 135, 'PG', 37),
#  ('BUCKET BROTHERHOOD', 133, 'PG', 38),
#  ('MALLRATS UNITED', 133, 'PG', 38),
#  ('NECKLACE OUTBREAK', 132, 'PG', 39),
#  ('SKY MIRACLE', 132, 'PG', 39),
#  ('VOLUME HOUSE', 132, 'PG', 39),
#  ('OPEN AFRICAN', 131, 'PG', 40),
#  ('MAJESTIC FLOATS', 130, 'PG', 41),
#  ('UNFORGIVEN ZOOLANDER', 129, 'PG', 42),
#  ('HOLES BRANNIGAN', 128, 'PG', 43),
#  ('JEDI BENEATH', 128, 'PG', 43),
#  ('PAPI NECKLACE', 128, 'PG', 43),
#  ('CHICKEN HELLFIGHTERS', 122, 'PG', 44),
#  ('MIGHTY LUCK', 122, 'PG', 44),
#  ('ARIZONA BANG', 121, 'PG', 45),
#  ('BRANNIGAN SUNRISE', 121, 'PG', 45),
#  ('DANGEROUS UPTOWN', 121, 'PG', 45),
#  ('JAWBREAKER BROOKLYN', 118, 'PG', 46),
#  ('OTHERS SOUP', 118, 'PG', 46),
#  ('PATHS CONTROL', 118, 'PG', 46),
#  ('GRAFFITI LOVE', 117, 'PG', 47),
#  ('MAGIC MALLRATS', 117, 'PG', 47),
#  ('RESURRECTION SILVERADO', 117, 'PG', 47),
#  ('INSTINCT AIRPORT', 116, 'PG', 48),
#  ('WORDS HUNTER', 116, 'PG', 48),
#  ('OSCAR GOLD', 115, 'PG', 49),
#  ('POTTER CONNECTICUT', 115, 'PG', 49),
#  ('CARRIE BUNCH', 114, 'PG', 50),
#  ('CHAINSAW UPTOWN', 114, 'PG', 50),
#  ('CHASING FIGHT', 114, 'PG', 50),
#  ('SUGAR WONKA', 114, 'PG', 50),
#  ('SUPERFLY TRIP', 114, 'PG', 50),
#  ('AMADEUS HOLY', 113, 'PG', 51),
#  ('LEGALLY SECRETARY', 113, 'PG', 51),
#  ('WONDERLAND CHRISTMAS', 111, 'PG', 52),
#  ('SNATCH SLIPPER', 110, 'PG', 53),
#  ('EFFECT GLADIATOR', 107, 'PG', 54),
#  ('HATE HANDICAP', 107, 'PG', 54),
#  ('MONSTER SPARTACUS', 107, 'PG', 54),
#  ('PARTY KNOCK', 107, 'PG', 54),
#  ('DALMATIONS SWEDEN', 106, 'PG', 55),
#  ('GASLIGHT CRUSADE', 106, 'PG', 55),
#  ('PRIVATE DROP', 106, 'PG', 55),
#  ('WON DARES', 105, 'PG', 56),
#  ('CROW GREASE', 104, 'PG', 57),
#  ('PINOCCHIO SIMON', 103, 'PG', 58),
#  ('BOILED DARES', 102, 'PG', 59),
#  ('CIDER DESIRE', 101, 'PG', 60),
#  ('BEHAVIOR RUNAWAY', 100, 'PG', 61),
#  ('PIRATES ROXANNE', 100, 'PG', 61),
#  ('PUNK DIVORCE', 100, 'PG', 61),
#  ('FRENCH HOLIDAY', 99, 'PG', 62),
#  ('PET HAUNTING', 99, 'PG', 62),
#  ('SABRINA MIDNIGHT', 99, 'PG', 62),
#  ('BOUND CHEAPER', 98, 'PG', 63),
#  ('SENSIBILITY REAR', 98, 'PG', 63),
#  ('EXPENDABLE STALLION', 97, 'PG', 64),
#  ('INVASION CYCLONE', 97, 'PG', 64),
#  ('DRUMS DYNAMITE', 96, 'PG', 65),
#  ('HORN WORKING', 95, 'PG', 66),
#  ('FULL FLATLINERS', 94, 'PG', 67),
#  ('BILL OTHERS', 93, 'PG', 68),
#  ('SHANE DARKNESS', 93, 'PG', 68),
#  ('OPPOSITE NECKLACE', 92, 'PG', 69),
#  ('FATAL HAUNTED', 91, 'PG', 70),
#  ('TITANS JERK', 91, 'PG', 70),
#  ('SECRET GROUNDHOG', 90, 'PG', 71),
#  ('TREATMENT JEKYLL', 87, 'PG', 72),
#  ('ACADEMY DINOSAUR', 86, 'PG', 73),
#  ('BLACKOUT PRIVATE', 85, 'PG', 74),
#  ('EGYPT TENENBAUMS', 85, 'PG', 74),
#  ('LOLA AGENT', 85, 'PG', 74),
#  ('STAGE WORLD', 85, 'PG', 74),
#  ('WASTELAND DIVINE', 85, 'PG', 74),
#  ('UPTOWN YOUNG', 84, 'PG', 75),
#  ('MOON BUNCH', 83, 'PG', 76),
#  ('FROST HEAD', 82, 'PG', 77),
#  ('LOSER HUSTLER', 80, 'PG', 78),
#  ('PEAK FOREVER', 80, 'PG', 78),
#  ('SEA VIRGIN', 80, 'PG', 78),
#  ('SHAWSHANK BUBBLE', 80, 'PG', 78),
#  ('WATCH TRACY', 78, 'PG', 79),
#  ('HELLFIGHTERS SIERRA', 75, 'PG', 80),
#  ('NEWTON LABYRINTH', 75, 'PG', 80),
#  ('WIZARD COLDBLOODED', 75, 'PG', 80),
#  ('MODERN DORADO', 74, 'PG', 81),
#  ('RAINBOW SHOCK', 74, 'PG', 81),
#  ('SILVERADO GOLDFINGER', 74, 'PG', 81),
#  ('BEDAZZLED MARRIED', 73, 'PG', 82),
#  ('MUSKETEERS WAIT', 73, 'PG', 82),
#  ('FICTION CHRISTMAS', 72, 'PG', 83),
#  ('TEMPLE ATTRACTION', 71, 'PG', 84),
#  ('WEDDING APOLLO', 70, 'PG', 85),
#  ('HOLLYWOOD ANONYMOUS', 69, 'PG', 86),
#  ('TOMATOES HELLFIGHTERS', 68, 'PG', 87),
#  ('EGG IGBY', 67, 'PG', 88),
#  ('LADY STAGE', 67, 'PG', 88),
#  ('CHARADE DUFFEL', 66, 'PG', 89),
#  ('LOVELY JINGLE', 65, 'PG', 90),
#  ('PATRIOT ROMAN', 65, 'PG', 90),
#  ('MILE MULAN', 64, 'PG', 91),
#  ('CHINATOWN GLADIATOR', 61, 'PG', 92),
#  ('POLISH BROOKLYN', 61, 'PG', 92),
#  ('TROUBLE DATE', 61, 'PG', 92),
#  ('JERSEY SASSY', 60, 'PG', 93),
#  ('MOCKINGBIRD HOLLYWOOD', 60, 'PG', 93),
#  ('ROOM ROMAN', 60, 'PG', 93),
#  ('LEGEND JEDI', 59, 'PG', 94),
#  ('JEKYLL FROGMEN', 58, 'PG', 95),
#  ('OKLAHOMA JUMANJI', 58, 'PG', 95),
#  ('SUPER WYOMING', 58, 'PG', 95),
#  ('DAWN POND', 57, 'PG', 96),
#  ('GOODFELLAS SALUTE', 56, 'PG', 97),
#  ('COAST RAINBOW', 55, 'PG', 98),
#  ('MOVIE SHAKESPEARE', 53, 'PG', 99),
#  ('TEQUILA PAST', 53, 'PG', 99),
#  ('TROJAN TOMORROW', 52, 'PG', 100),
#  ('CHAMPION FLATLINERS', 51, 'PG', 101),
#  ('FRISCO FORREST', 51, 'PG', 101),
#  ('LION UNCUT', 50, 'PG', 102),
#  ('MUPPET MILE', 50, 'PG', 102),
#  ('PILOT HOOSIERS', 50, 'PG', 102),
#  ('HURRICANE AFFAIR', 49, 'PG', 103),
#  ('HEAVEN FREEDOM', 48, 'PG', 104),
#  ('PELICAN COMFORTS', 48, 'PG', 104),
#  ('RUSH GOODFELLAS', 48, 'PG', 104),
#  ('SHANGHAI TYCOON', 47, 'PG', 105),
#  ('SUSPECTS QUILLS', 47, 'PG', 105),
#  ('IRON MOON', 46, 'PG', 106),
#  ('CHICAGO NORTH', 185, 'PG-13', 1),
#  ('GANGS PRIDE', 185, 'PG-13', 1),
#  ('POND SEATTLE', 185, 'PG-13', 1),
#  ('CONSPIRACY SPIRIT', 184, 'PG-13', 2),
#  ('THEORY MERMAID', 184, 'PG-13', 2),
#  ('FRONTIER CABIN', 183, 'PG-13', 3),
#  ('REDS POCUS', 182, 'PG-13', 4),
#  ('HOTEL HAPPINESS', 181, 'PG-13', 5),
#  ('JACKET FRISCO', 181, 'PG-13', 5),
#  ('IMPACT ALADDIN', 180, 'PG-13', 6),
#  ('MIXED DOORS', 180, 'PG-13', 6),
#  ('NASH CHOCOLAT', 180, 'PG-13', 6),
#  ('KICK SAVANNAH', 179, 'PG-13', 7),
#  ('VIRGIN DAISY', 179, 'PG-13', 7),
#  ('FURY MURDER', 178, 'PG-13', 8),
#  ('IMAGE PRINCESS', 178, 'PG-13', 8),
#  ('INNOCENT USUAL', 178, 'PG-13', 8),
#  ('MADNESS ATTACKS', 178, 'PG-13', 8),
#  ('NAME DETECTIVE', 178, 'PG-13', 8),
#  ('ROCKETEER MOTHER', 178, 'PG-13', 8),
#  ('WRONG BEHAVIOR', 178, 'PG-13', 8),
#  ('BRAVEHEART HUMAN', 176, 'PG-13', 9),
#  ('GATHERING CALENDAR', 176, 'PG-13', 9),
#  ('EVOLUTION ALTER', 174, 'PG-13', 10),
#  ('VIETNAM SMOOCHY', 174, 'PG-13', 10),
#  ('EYES DRIVING', 172, 'PG-13', 11),
#  ('IDAHO LOVE', 172, 'PG-13', 11),
#  ('UNCUT SUICIDES', 172, 'PG-13', 11),
#  ('MAGNOLIA FORRESTER', 171, 'PG-13', 12),
#  ('MOONSHINE CABIN', 171, 'PG-13', 12),
#  ('WORLD LEATHERNECKS', 171, 'PG-13', 12),
#  ('BREAKING HOME', 169, 'PG-13', 13),
#  ('TRANSLATION SUMMER', 168, 'PG-13', 14),
#  ('SHOW LORD', 167, 'PG-13', 15),
#  ('CONTACT ANONYMOUS', 166, 'PG-13', 16),
#  ('MINE TITANS', 166, 'PG-13', 16),
#  ('DARLING BREAKING', 165, 'PG-13', 17),
#  ('SONG HEDWIG', 165, 'PG-13', 17),
#  ('SPEAKEASY DATE', 165, 'PG-13', 17),
#  ('MISSION ZOOLANDER', 164, 'PG-13', 18),
#  ('CASPER DRAGONFLY', 163, 'PG-13', 19),
#  ('KISS GLORY', 163, 'PG-13', 19),
#  ('LOVERBOY ATTACKS', 162, 'PG-13', 20),
#  ('MIRACLE VIRTUAL', 162, 'PG-13', 20),
#  ('ROSES TREASURE', 162, 'PG-13', 20),
#  ('METAL ARMAGEDDON', 161, 'PG-13', 21),
#  ('PEACH INNOCENT', 160, 'PG-13', 22),
#  ('DRIVER ANNIE', 159, 'PG-13', 23),
#  ('POSEIDON FOREVER', 159, 'PG-13', 23),
#  ('HOBBIT ALIEN', 157, 'PG-13', 24),
#  ('PAST SUICIDES', 157, 'PG-13', 24),
#  ('SLIPPER FIDELITY', 156, 'PG-13', 25),
#  ('PSYCHO SHRUNK', 155, 'PG-13', 26),
#  ('SHREK LICENSE', 154, 'PG-13', 27),
#  ('APOLLO TEEN', 153, 'PG-13', 28),
#  ('LEATHERNECKS DWARFS', 153, 'PG-13', 28),
#  ('RIGHT CRANES', 153, 'PG-13', 28),
#  ('ROLLERCOASTER BRINGING', 153, 'PG-13', 28),
#  ('SISTER FREDDY', 152, 'PG-13', 29),
#  ('TELEMARK HEARTBREAKERS', 152, 'PG-13', 29),
#  ('TOURIST PELICAN', 152, 'PG-13', 29),
#  ('BEETHOVEN EXORCIST', 151, 'PG-13', 30),
#  ('HUNCHBACK IMPOSSIBLE', 151, 'PG-13', 30),
#  ('MASKED BUBBLE', 151, 'PG-13', 30),
#  ('SCHOOL JACKET', 151, 'PG-13', 30),
#  ('BINGO TALENTED', 150, 'PG-13', 31),
#  ('CLEOPATRA DEVIL', 150, 'PG-13', 31),
#  ('RUSHMORE MERMAID', 150, 'PG-13', 31),
#  ('MINDS TRUMAN', 149, 'PG-13', 32),
#  ('RIVER OUTLAW', 149, 'PG-13', 32),
#  ('FLINTSTONES HAPPINESS', 148, 'PG-13', 33),
#  ('OUTLAW HANKY', 148, 'PG-13', 33),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 147, 'PG-13', 34),
#  ('HALF OUTFIELD', 146, 'PG-13', 35),
#  ('FLOATS GARDEN', 145, 'PG-13', 36),
#  ('PAYCHECK WAIT', 145, 'PG-13', 36),
#  ('ROCKY WAR', 145, 'PG-13', 36),
#  ('FACTORY DRAGON', 144, 'PG-13', 37),
#  ('LAMBS CINCINATTI', 144, 'PG-13', 37),
#  ('STRICTLY SCARFACE', 144, 'PG-13', 37),
#  ('CLOCKWORK PARADISE', 143, 'PG-13', 38),
#  ('CROOKED FROGMEN', 143, 'PG-13', 38),
#  ('DETECTIVE VISION', 143, 'PG-13', 38),
#  ('MILLION ACE', 142, 'PG-13', 39),
#  ('DYNAMITE TARZAN', 141, 'PG-13', 40),
#  ('HOMICIDE PEACH', 141, 'PG-13', 40),
#  ('CLYDE THEORY', 139, 'PG-13', 41),
#  ('GROUNDHOG UNCUT', 139, 'PG-13', 41),
#  ('VOICE PEACH', 139, 'PG-13', 41),
#  ('EXPECATIONS NATURAL', 138, 'PG-13', 42),
#  ('SPINAL ROCKY', 138, 'PG-13', 42),
#  ('SPIRITED CASUALTIES', 138, 'PG-13', 42),
#  ('PHILADELPHIA WIFE', 137, 'PG-13', 43),
#  ('MAKER GABLES', 136, 'PG-13', 44),
#  ('REAP UNFAITHFUL', 136, 'PG-13', 44),
#  ('SUNRISE LEAGUE', 135, 'PG-13', 45),
#  ('THIEF PELICAN', 135, 'PG-13', 45),
#  ('PITTSBURGH HUNCHBACK', 134, 'PG-13', 46),
#  ('CURTAIN VIDEOTAPE', 133, 'PG-13', 47),
#  ('FREEDOM CLEOPATRA', 133, 'PG-13', 47),
#  ('PLATOON INSTINCT', 132, 'PG-13', 48),
#  ('STREAK RIDGEMONT', 132, 'PG-13', 48),
#  ('TRAINSPOTTING STRANGERS', 132, 'PG-13', 48),
#  ('STALLION SUNDANCE', 130, 'PG-13', 49),
#  ('SLEEPING SUSPECTS', 129, 'PG-13', 50),
#  ('USUAL UNTOUCHABLES', 128, 'PG-13', 51),
#  ('ARGONAUTS TOWN', 127, 'PG-13', 52),
#  ('GUNFIGHTER MUSSOLINI', 127, 'PG-13', 52),
#  ('MALTESE HOPE', 127, 'PG-13', 52),
#  ('ELEPHANT TROJAN', 126, 'PG-13', 53),
#  ('SINNERS ATLANTIS', 126, 'PG-13', 53),
#  ('HUNTER ALTER', 125, 'PG-13', 54),
#  ('JINGLE SAGEBRUSH', 124, 'PG-13', 55),
#  ('SPEED SUIT', 124, 'PG-13', 55),
#  ('SWARM GOLD', 123, 'PG-13', 56),
#  ('CONFUSED CANDLES', 122, 'PG-13', 57),
#  ('HARRY IDAHO', 121, 'PG-13', 58),
#  ('PARIS WEEKEND', 121, 'PG-13', 58),
#  ('COMMAND DARLING', 120, 'PG-13', 59),
#  ('DOLLS RAGE', 120, 'PG-13', 59),
#  ('KARATE MOON', 120, 'PG-13', 59),
#  ('ORDER BETRAYED', 120, 'PG-13', 59),
#  ('GAMES BOWFINGER', 119, 'PG-13', 60),
#  ('IDENTITY LOVER', 119, 'PG-13', 60),
#  ('BACKLASH UNDEFEATED', 118, 'PG-13', 61),
#  ('PERSONAL LADYBUGS', 118, 'PG-13', 61),
#  ('GLORY TRACY', 115, 'PG-13', 62),
#  ('ALABAMA DEVIL', 114, 'PG-13', 63),
#  ('BLADE POLISH', 114, 'PG-13', 63),
#  ('ATTACKS HATE', 113, 'PG-13', 64),
#  ('SPY MILE', 112, 'PG-13', 65),
#  ('WAIT CIDER', 112, 'PG-13', 65),
#  ('CELEBRITY HORN', 110, 'PG-13', 66),
#  ('LEAGUE HELLFIGHTERS', 110, 'PG-13', 66),
#  ('SEATTLE EXPECATIONS', 110, 'PG-13', 66),
#  ('PARK CITIZEN', 109, 'PG-13', 67),
#  ('RUGRATS SHAKESPEARE', 109, 'PG-13', 67),
#  ('WHALE BIKINI', 109, 'PG-13', 67),
#  ('LORD ARIZONA', 108, 'PG-13', 68),
#  ('INTENTIONS EMPIRE', 107, 'PG-13', 69),
#  ('UNDEFEATED DALMATIONS', 107, 'PG-13', 69),
#  ('WANDA CHAMBER', 107, 'PG-13', 69),
#  ('MICROCOSMOS PARADISE', 105, 'PG-13', 70),
#  ('FEATHERS METAL', 104, 'PG-13', 71),
#  ('BLINDNESS GUN', 103, 'PG-13', 72),
#  ('FALCON VOLUME', 102, 'PG-13', 73),
#  ('ROBBERS JOON', 102, 'PG-13', 73),
#  ('SCARFACE BANG', 102, 'PG-13', 73),
#  ('TREASURE COMMAND', 102, 'PG-13', 73),
#  ('BILKO ANONYMOUS', 100, 'PG-13', 74),
#  ('WYOMING STORM', 100, 'PG-13', 74),
#  ('TENENBAUMS COMMAND', 99, 'PG-13', 75),
#  ('LOST BIRD', 98, 'PG-13', 76),
#  ('MADRE GABLES', 98, 'PG-13', 76),
#  ('PREJUDICE OLEANDER', 98, 'PG-13', 76),
#  ('LUCKY FLYING', 97, 'PG-13', 77),
#  ('CORE SUIT', 92, 'PG-13', 78),
#  ('ANTHEM LUKE', 91, 'PG-13', 79),
#  ('TARZAN VIDEOTAPE', 91, 'PG-13', 79),
#  ('BASIC EASY', 90, 'PG-13', 80),
#  ('CIRCUS YOUTH', 90, 'PG-13', 80),
#  ('DARES PLUTO', 89, 'PG-13', 81),
#  ('ROOTS REMEMBER', 89, 'PG-13', 81),
#  ('CONGENIALITY QUEST', 87, 'PG-13', 82),
#  ('GANDHI KWAI', 86, 'PG-13', 83),
#  ('PACKER MADIGAN', 84, 'PG-13', 84),
#  ('SAVANNAH TOWN', 84, 'PG-13', 84),
#  ('ATTRACTION NEWTON', 83, 'PG-13', 85),
#  ('PERFECT GROOVE', 82, 'PG-13', 86),
#  ('RAIDERS ANTITRUST', 82, 'PG-13', 86),
#  ('REIGN GENTLEMEN', 82, 'PG-13', 86),
#  ('FLAMINGOS CONNECTICUT', 80, 'PG-13', 87),
#  ('SADDLE ANTITRUST', 80, 'PG-13', 87),
#  ('MOULIN WAKE', 79, 'PG-13', 88),
#  ('SHOCK CABIN', 79, 'PG-13', 88),
#  ('HOLIDAY GAMES', 78, 'PG-13', 89),
#  ('VOYAGE LEGALLY', 78, 'PG-13', 89),
#  ('BERETS AGENT', 77, 'PG-13', 90),
#  ('DESTINATION JERK', 76, 'PG-13', 91),
#  ('ORANGE GRAPES', 76, 'PG-13', 91),
#  ('VILLAIN DESPERATE', 76, 'PG-13', 91),
#  ('NETWORK PEAK', 75, 'PG-13', 92),
#  ('SNATCHERS MONTEZUMA', 74, 'PG-13', 93),
#  ('BRIGHT ENCOUNTERS', 73, 'PG-13', 94),
#  ('KNOCK WARLOCK', 71, 'PG-13', 95),
#  ('MANNEQUIN WORST', 71, 'PG-13', 95),
#  ('LOUISIANA HARRY', 70, 'PG-13', 96),
#  ('LEBOWSKI SOLDIERS', 69, 'PG-13', 97),
#  ('DIVIDE MONSTER', 68, 'PG-13', 98),
#  ('BUTCH PANTHER', 67, 'PG-13', 99),
#  ('SHOOTIST SUPERFLY', 67, 'PG-13', 99),
#  ('CLUB GRAFFITI', 65, 'PG-13', 100),
#  ('CONFESSIONS MAGUIRE', 65, 'PG-13', 100),
#  ('METROPOLIS COMA', 64, 'PG-13', 101),
#  ('TAXI KICK', 64, 'PG-13', 101),
#  ('TRIP NEWTON', 64, 'PG-13', 101),
#  ('VICTORY ACADEMY', 64, 'PG-13', 101),
#  ('INTOLERABLE INTENTIONS', 63, 'PG-13', 102),
#  ('AIRPLANE SIERRA', 62, 'PG-13', 103),
#  ('DRIFTER COMMANDMENTS', 61, 'PG-13', 104),
#  ('RESERVOIR ADAPTATION', 61, 'PG-13', 104),
#  ('SHAKESPEARE SADDLE', 60, 'PG-13', 105),
#  ('DAUGHTER MADIGAN', 59, 'PG-13', 106),
#  ('VISION TORQUE', 59, 'PG-13', 106),
#  ('WHISPERER GIANT', 59, 'PG-13', 106),
#  ('FANTASY TROOPERS', 58, 'PG-13', 107),
#  ('ALTER VICTORY', 57, 'PG-13', 108),
#  ('MATRIX SNOWMAN', 56, 'PG-13', 109),
#  ('JUGGLER HARDLY', 54, 'PG-13', 110),
#  ('OCTOBER SUBMARINE', 54, 'PG-13', 110),
#  ('THIN SAGEBRUSH', 53, 'PG-13', 111),
#  ('DEEP CRUSADE', 51, 'PG-13', 112),
#  ('ENGLISH BULWORTH', 51, 'PG-13', 112),
#  ('NATURAL STOCK', 50, 'PG-13', 113),
#  ('SMOKING BARBARELLA', 50, 'PG-13', 113),
#  ('NOTTING SPEAKEASY', 48, 'PG-13', 114),
#  ('PARADISE SABRINA', 48, 'PG-13', 114),
#  ('VALENTINE VANISHING', 48, 'PG-13', 114),
#  ('HALLOWEEN NUTS', 47, 'PG-13', 115),
#  ('HAWK CHILL', 47, 'PG-13', 115),
#  ('KWAI HOMEWARD', 46, 'PG-13', 116),
#  ('LABYRINTH LEAGUE', 46, 'PG-13', 116),
#  ('RIDGEMONT SUBMARINE', 46, 'PG-13', 116),
#  ('HOME PITY', 185, 'R', 1),
#  ('SOLDIERS EVOLUTION', 185, 'R', 1),
#  ('SWEET BROTHERHOOD', 185, 'R', 1),
#  ('SMOOCHY CONTROL', 184, 'R', 2),
#  ('SATURN NAME', 182, 'R', 3),
#  ('ANALYZE HOOSIERS', 181, 'R', 4),
#  ('HAUNTING PIANIST', 181, 'R', 4),
#  ('LOVE SUICIDES', 181, 'R', 4),
#  ('WILD APOLLO', 181, 'R', 4),
#  ('CAUSE DATE', 179, 'R', 5),
#  ('FLIGHT LIES', 179, 'R', 5),
#  ('SLACKER LIAISONS', 179, 'R', 5),
#  ('DROP WATERFRONT', 178, 'R', 6),
#  ('EXPRESS LONELY', 178, 'R', 6),
#  ('DOUBLE WRATH', 177, 'R', 7),
#  ('QUEST MUSSOLINI', 177, 'R', 7),
#  ('ENTRAPMENT SATISFACTION', 176, 'R', 8),
#  ('LIGHTS DEER', 174, 'R', 9),
#  ('FIRE WOLVES', 173, 'R', 10),
#  ('VELVET TERMINATOR', 173, 'R', 10),
#  ('CONNECTICUT TRAMP', 172, 'R', 11),
#  ('TIGHTS DAWN', 172, 'R', 11),
#  ('KRAMER CHOCOLATE', 171, 'R', 12),
#  ('ROXANNE REBEL', 171, 'R', 12),
#  ('SOUP WISDOM', 169, 'R', 13),
#  ('CAMPUS REMEMBER', 167, 'R', 14),
#  ('ESCAPE METROPOLIS', 167, 'R', 14),
#  ('REQUIEM TYCOON', 167, 'R', 14),
#  ('GREEDY ROOTS', 166, 'R', 15),
#  ('MASSACRE USUAL', 165, 'R', 16),
#  ('UNITED PILOT', 164, 'R', 17),
#  ('VIRGINIAN PLUTO', 164, 'R', 17),
#  ('GILMORE BOILED', 163, 'R', 18),
#  ('STORY SIDE', 163, 'R', 18),
#  ('BADMAN DAWN', 162, 'R', 19),
#  ('BROOKLYN DESERT', 161, 'R', 20),
#  ('KILLER INNOCENT', 161, 'R', 20),
#  ('NEIGHBORS CHARADE', 161, 'R', 20),
#  ('WASH HEAVENLY', 161, 'R', 20),
#  ('BEAR GRACELAND', 160, 'R', 21),
#  ('FEVER EMPIRE', 158, 'R', 22),
#  ('ROAD ROXANNE', 158, 'R', 22),
#  ('FINDING ANACONDA', 156, 'R', 23),
#  ('FAMILY SWEET', 155, 'R', 24),
#  ('DOUBTFIRE LABYRINTH', 154, 'R', 25),
#  ('DURHAM PANKY', 154, 'R', 25),
#  ('GOLD RIVER', 154, 'R', 25),
#  ('RAGING AIRPLANE', 154, 'R', 25),
#  ('GOLDMINE TYCOON', 153, 'R', 26),
#  ('RULES HUMAN', 153, 'R', 26),
#  ('TUXEDO MILE', 152, 'R', 27),
#  ('STRAIGHT HOURS', 151, 'R', 28),
#  ('GRINCH MASSAGE', 150, 'R', 29),
#  ('HOLOCAUST HIGHBALL', 149, 'R', 30),
#  ('SPIRIT FLINTSTONES', 149, 'R', 30),
#  ('ARMY FLINTSTONES', 148, 'R', 31),
#  ('MADISON TRAP', 147, 'R', 32),
#  ('HAMLET WISDOM', 146, 'R', 33),
#  ('RUN PACIFIC', 145, 'R', 34),
#  ('VACATION BOONDOCK', 145, 'R', 34),
#  ('SOUTH WAIT', 143, 'R', 35),
#  ('TOMORROW HUSTLER', 142, 'R', 36),
#  ('VANISHED GARDEN', 142, 'R', 36),
#  ('KISSING DOLLS', 141, 'R', 37),
#  ('SUN CONFESSIONS', 141, 'R', 37),
#  ('GRACELAND DYNAMITE', 140, 'R', 38),
#  ('LOATHING LEGALLY', 140, 'R', 38),
#  ('HORROR REIGN', 139, 'R', 39),
#  ('SHRUNK DIVINE', 139, 'R', 39),
#  ('WORKER TARZAN', 139, 'R', 39),
#  ('LOSE INCH', 137, 'R', 40),
#  ('WILLOW TRACY', 137, 'R', 40),
#  ('TOWN ARK', 136, 'R', 41),
#  ('ROBBERY BRIGHT', 134, 'R', 42),
#  ('SPLENDOR PATTON', 134, 'R', 42),
#  ('WEEKEND PERSONAL', 134, 'R', 42),
#  ('CHOCOLATE DUCK', 132, 'R', 43),
#  ('ICE CROSSING', 131, 'R', 44),
#  ('AMERICAN CIRCUS', 129, 'R', 45),
#  ('MUSIC BOONDOCK', 129, 'R', 45),
#  ('GALAXY SWEETHEARTS', 128, 'R', 46),
#  ('SEVEN SWARM', 127, 'R', 47),
#  ('SUBMARINE BED', 127, 'R', 47),
#  ('FREAKY POCUS', 126, 'R', 48),
#  ('PAJAMA JAWBREAKER', 126, 'R', 48),
#  ('WOMEN DORADO', 126, 'R', 48),
#  ('FISH OPUS', 125, 'R', 49),
#  ('CLONES PINOCCHIO', 124, 'R', 50),
#  ('ILLUSION AMELIE', 122, 'R', 51),
#  ('BOOGIE AMELIE', 121, 'R', 52),
#  ('LOCK REAR', 120, 'R', 53),
#  ('RAGE GAMES', 120, 'R', 53),
#  ('APOCALYPSE FLAMINGOS', 119, 'R', 54),
#  ('STRANGERS GRAFFITI', 119, 'R', 54),
#  ('ORIENT CLOSER', 118, 'R', 55),
#  ('MADIGAN DORADO', 116, 'R', 56),
#  ('PRIX UNDEFEATED', 115, 'R', 57),
#  ('TROOPERS METAL', 115, 'R', 57),
#  ('BANGER PINOCCHIO', 113, 'R', 58),
#  ('SHEPHERD MIDSUMMER', 113, 'R', 58),
#  ('CONVERSATION DOWNHILL', 112, 'R', 59),
#  ('CROWDS TELEMARK', 112, 'R', 59),
#  ('CRUSADE HONEY', 112, 'R', 59),
#  ('QUILLS BULL', 112, 'R', 59),
#  ('STAGECOACH ARMAGEDDON', 112, 'R', 59),
#  ('FROGMEN BREAKING', 111, 'R', 60),
#  ('SIEGE MADRE', 111, 'R', 60),
#  ('SUIT WALLS', 111, 'R', 60),
#  ('TIES HUNGER', 111, 'R', 60),
#  ('WIND PHANTOM', 111, 'R', 60),
#  ('HIGHBALL POTTER', 110, 'R', 61),
#  ('REMEMBER DIARY', 110, 'R', 61),
#  ('HOUSE DYNAMITE', 109, 'R', 62),
#  ('GORGEOUS BINGO', 108, 'R', 63),
#  ('HANDICAP BOONDOCK', 108, 'R', 63),
#  ('DATE SPEED', 104, 'R', 64),
#  ('SHIP WONDERLAND', 104, 'R', 64),
#  ('TITANIC BOONDOCK', 104, 'R', 64),
#  ('HOMEWARD CIDER', 103, 'R', 65),
#  ('MOTHER OLEANDER', 103, 'R', 65),
#  ('GIANT TROOPERS', 102, 'R', 66),
#  ('JEOPARDY ENCINO', 102, 'R', 66),
#  ('OPUS ICE', 102, 'R', 66),
#  ('GHOSTBUSTERS ELF', 101, 'R', 67),
#  ('ROOF CHAMPION', 101, 'R', 67),
#  ('ZOOLANDER FICTION', 101, 'R', 67),
#  ('DELIVERANCE MULHOLLAND', 100, 'R', 68),
#  ('DIVINE RESURRECTION', 100, 'R', 68),
#  ('EARRING INSTINCT', 98, 'R', 69),
#  ('FEUD FROGMEN', 98, 'R', 69),
#  ('WISDOM WORKER', 98, 'R', 69),
#  ('CLUELESS BUCKET', 95, 'R', 70),
#  ('DISTURBING SCARFACE', 94, 'R', 71),
#  ('ANACONDA CONFESSIONS', 92, 'R', 72),
#  ('KANE EXORCIST', 92, 'R', 72),
#  ('FIGHT JAWBREAKER', 91, 'R', 73),
#  ('VERTIGO NORTHWEST', 90, 'R', 74),
#  ('BEAST HUNCHBACK', 89, 'R', 75),
#  ('DETAILS PACKER', 88, 'R', 76),
#  ('HOLY TADPOLE', 88, 'R', 76),
#  ('PURPLE MOVIE', 88, 'R', 76),
#  ('TERMINATOR CLUB', 88, 'R', 76),
#  ('DEVIL DESIRE', 87, 'R', 77),
#  ('YENTL IDAHO', 86, 'R', 78),
#  ('BEVERLY OUTLAW', 85, 'R', 79),
#  ('CANYON STOCK', 85, 'R', 79),
#  ('OZ LIAISONS', 85, 'R', 79),
#  ('WINDOW SIDE', 85, 'R', 79),
#  ('GONE TROUBLE', 84, 'R', 80),
#  ('GUYS FALCON', 84, 'R', 80),
#  ('HIGH ENCINO', 84, 'R', 80),
#  ('HONEY TIES', 84, 'R', 80),
#  ('JEEPERS WEDDING', 84, 'R', 80),
#  ('PLUTO OLEANDER', 84, 'R', 80),
#  ('SLING LUKE', 84, 'R', 80),
#  ('FUGITIVE MAGUIRE', 83, 'R', 81),
#  ('ALONE TRIP', 82, 'R', 82),
#  ('ANYTHING SAVANNAH', 82, 'R', 82),
#  ('AMELIE HELLFIGHTERS', 79, 'R', 83),
#  ('ISHTAR ROCKETEER', 79, 'R', 83),
#  ('UNFAITHFUL KILL', 78, 'R', 84),
#  ('FIDDLER LOST', 75, 'R', 85),
#  ('STAMPEDE DISTURBING', 75, 'R', 85),
#  ('WORKING MICROCOSMOS', 74, 'R', 86),
#  ('BROTHERHOOD BLANKET', 73, 'R', 87),
#  ('FRIDA SLIPPER', 73, 'R', 87),
#  ('SALUTE APOLLO', 73, 'R', 87),
#  ('STREETCAR INTENTIONS', 73, 'R', 87),
#  ('HARDLY ROBBERS', 72, 'R', 88),
#  ('MAUDE MOD', 72, 'R', 88),
#  ('CHARIOTS CONSPIRACY', 71, 'R', 89),
#  ('TRAIN BUNCH', 71, 'R', 89),
#  ('CANDIDATE PERDITION', 70, 'R', 90),
#  ('CHANCE RESURRECTION', 70, 'R', 90),
#  ('HEAD STRANGER', 69, 'R', 91),
#  ('DOOM DANCING', 68, 'R', 92),
#  ('COMANCHEROS ENEMY', 67, 'R', 93),
#  ('SILENCE KANE', 67, 'R', 93),
#  ('DESERT POSEIDON', 64, 'R', 94),
#  ('BOULEVARD MOB', 63, 'R', 95),
#  ('DINOSAUR SECRETARY', 63, 'R', 95),
#  ('FORREST SONS', 63, 'R', 95),
#  ('REUNION WITCHES', 63, 'R', 95),
#  ('BUBBLE GROSSE', 60, 'R', 96),
#  ('COMMANDMENTS EXPRESS', 59, 'R', 97),
#  ('INTERVIEW LIAISONS', 59, 'R', 97),
#  ('JET NEIGHBORS', 59, 'R', 97),
#  ('CLOSER BANG', 58, 'R', 98),
#  ('CUPBOARD SINNERS', 56, 'R', 99),
#  ('AIRPORT POLLOCK', 54, 'R', 100),
#  ('GO PURPLE', 54, 'R', 100),
#  ('SENSE GREEK', 54, 'R', 100),
#  ('MAGNIFICENT CHITTY', 53, 'R', 101),
#  ('CROSSING DIVORCE', 50, 'R', 102),
#  ('GROSSE WONDERFUL', 49, 'R', 103),
#  ('CRYSTAL BREAKING', 184, 'NC-17', 1),
#  ('KING EVOLUTION', 184, 'NC-17', 1),
#  ('SONS INTERVIEW', 184, 'NC-17', 1),
#  ('SORORITY QUEEN', 184, 'NC-17', 1),
#  ('SCALAWAG DUCK', 183, 'NC-17', 2),
#  ('WIFE TURN', 183, 'NC-17', 2),
#  ('SEARCHERS WAIT', 182, 'NC-17', 3),
#  ('RUNAWAY TENENBAUMS', 181, 'NC-17', 4),
#  ('ALLEY EVOLUTION', 180, 'NC-17', 5),
#  ('CONFIDENTIAL INTERVIEW', 180, 'NC-17', 5),
#  ('SOMETHING DUCK', 180, 'NC-17', 5),
#  ('ANONYMOUS HUMAN', 179, 'NC-17', 6),
#  ('REDEMPTION COMFORTS', 179, 'NC-17', 6),
#  ('TEXAS WATCH', 179, 'NC-17', 6),
#  ('YOUTH KICK', 179, 'NC-17', 6),
#  ('DOZEN LION', 177, 'NC-17', 7),
#  ('WRATH MILE', 176, 'NC-17', 8),
#  ('DRIVING POLISH', 175, 'NC-17', 9),
#  ('LAWRENCE LOVE', 175, 'NC-17', 9),
#  ('MODEL FISH', 175, 'NC-17', 9),
#  ('JADE BUNCH', 174, 'NC-17', 10),
#  ('UPRISING UPTOWN', 174, 'NC-17', 10),
#  ('PIZZA JUMANJI', 173, 'NC-17', 11),
#  ('CREEPERS KANE', 172, 'NC-17', 12),
#  ('JERK PAYCHECK', 172, 'NC-17', 12),
#  ('JERICHO MULAN', 171, 'NC-17', 13),
#  ('ARTIST COLDBLOODED', 170, 'NC-17', 14),
#  ('DRAGON SQUAD', 170, 'NC-17', 14),
#  ('HEDWIG ALTER', 169, 'NC-17', 15),
#  ('OUTBREAK DIVINE', 169, 'NC-17', 15),
#  ('ANTITRUST TOMATOES', 168, 'NC-17', 16),
#  ('HAROLD FRENCH', 168, 'NC-17', 16),
#  ('INCH JET', 167, 'NC-17', 17),
#  ('LESSON CLEOPATRA', 167, 'NC-17', 17),
#  ('IGBY MAKER', 160, 'NC-17', 18),
#  ('MUMMY CREATURES', 160, 'NC-17', 18),
#  ('FRANKENSTEIN STRANGER', 159, 'NC-17', 19),
#  ('ENOUGH RAGING', 158, 'NC-17', 20),
#  ('INDEPENDENCE HOTEL', 157, 'NC-17', 21),
#  ('VOLCANO TEXAS', 157, 'NC-17', 21),
#  ('ELF MURDER', 155, 'NC-17', 22),
#  ('LOLITA WORLD', 155, 'NC-17', 22),
#  ('BABY HALL', 153, 'NC-17', 23),
#  ('EDGE KISSING', 153, 'NC-17', 23),
#  ('ELIZABETH SHANE', 152, 'NC-17', 24),
#  ('LUCK OPUS', 152, 'NC-17', 24),
#  ('CHRISTMAS MOONSHINE', 150, 'NC-17', 25),
#  ('DIRTY ACE', 147, 'NC-17', 26),
#  ('LIES TREATMENT', 147, 'NC-17', 26),
#  ('RACER EGG', 147, 'NC-17', 26),
#  ('CHAPLIN LICENSE', 146, 'NC-17', 27),
#  ('NUTS TIES', 145, 'NC-17', 28),
#  ('VIDEOTAPE ARSENIC', 145, 'NC-17', 28),
#  ('TOWERS HURRICANE', 144, 'NC-17', 29),
#  ('VIRTUAL SPOILERS', 144, 'NC-17', 29),
#  ('CINCINATTI WHISPERER', 143, 'NC-17', 30),
#  ('STEEL SANTA', 143, 'NC-17', 30),
#  ('BIKINI BORROWERS', 142, 'NC-17', 31),
#  ('SPICE SORORITY', 141, 'NC-17', 32),
#  ('EAGLES PANKY', 140, 'NC-17', 33),
#  ('CREATURES SHAKESPEARE', 139, 'NC-17', 34),
#  ('DORADO NOTTING', 139, 'NC-17', 34),
#  ('HOPE TOOTSIE', 139, 'NC-17', 34),
#  ('POCUS PULP', 138, 'NC-17', 35),
#  ('LIFE TWISTED', 137, 'NC-17', 36),
#  ('SCORPION APOLLO', 137, 'NC-17', 36),
#  ('HOLLOW JEOPARDY', 136, 'NC-17', 37),
#  ('PIANIST OUTFIELD', 136, 'NC-17', 37),
#  ('CANDLES GRAPES', 135, 'NC-17', 38),
#  ('INDIAN LOVE', 135, 'NC-17', 38),
#  ('SIERRA DIVIDE', 135, 'NC-17', 38),
#  ('JUNGLE CLOSER', 134, 'NC-17', 39),
#  ('DRAGONFLY STRANGERS', 133, 'NC-17', 40),
#  ('FOREVER CANDIDATE', 131, 'NC-17', 41),
#  ('NEMO CAMPUS', 131, 'NC-17', 41),
#  ('DARKO DORADO', 130, 'NC-17', 42),
#  ('JASON TRAP', 130, 'NC-17', 42),
#  ('OUTFIELD MASSACRE', 129, 'NC-17', 43),
#  ('NOTORIOUS REUNION', 128, 'NC-17', 44),
#  ('MONTEZUMA COMMAND', 126, 'NC-17', 45),
#  ('VAMPIRE WHALE', 126, 'NC-17', 45),
#  ('WONDERFUL DROP', 126, 'NC-17', 45),
#  ('BULL SHAWSHANK', 125, 'NC-17', 46),
#  ('DONNIE ALLEY', 125, 'NC-17', 46),
#  ('GENTLEMEN STAGE', 125, 'NC-17', 46),
#  ('FLASH WARS', 123, 'NC-17', 47),
#  ('INSECTS STONE', 123, 'NC-17', 47),
#  ('MASK PEACH', 123, 'NC-17', 47),
#  ('REEF SALUTE', 123, 'NC-17', 47),
#  ('VANISHING ROCKY', 123, 'NC-17', 47),
#  ('BETRAYED REAR', 122, 'NC-17', 48),
#  ('DECEIVER BETRAYED', 122, 'NC-17', 48),
#  ('HOURS RAGE', 122, 'NC-17', 48),
#  ('VANILLA DAY', 122, 'NC-17', 48),
#  ('PURE RUNNER', 121, 'NC-17', 49),
#  ('CALENDAR GUNFIGHT', 120, 'NC-17', 50),
#  ('UNTOUCHABLES SUNRISE', 120, 'NC-17', 50),
#  ('DUMBO LUST', 119, 'NC-17', 51),
#  ('ROUGE SQUAD', 118, 'NC-17', 52),
#  ('CHAMBER ITALIAN', 117, 'NC-17', 53),
#  ('DUCK RACER', 116, 'NC-17', 54),
#  ('ELEMENT FREDDY', 115, 'NC-17', 55),
#  ('PRIDE ALAMO', 114, 'NC-17', 56),
#  ('LADYBUGS ARMAGEDDON', 113, 'NC-17', 57),
#  ('STATE WASTELAND', 113, 'NC-17', 57),
#  ('CONEHEADS SMOOCHY', 112, 'NC-17', 58),
#  ('FORRESTER COMANCHEROS', 112, 'NC-17', 58),
#  ('SEABISCUIT PUNK', 112, 'NC-17', 58),
#  ('GROOVE FICTION', 111, 'NC-17', 59),
#  ('COMA HEAD', 109, 'NC-17', 60),
#  ('PANTHER REDS', 109, 'NC-17', 60),
#  ('HANKY OCTOBER', 107, 'NC-17', 61),
#  ('BED HIGHBALL', 106, 'NC-17', 62),
#  ('DEER VIRGINIAN', 106, 'NC-17', 62),
#  ('JOON NORTHWEST', 105, 'NC-17', 63),
#  ('ZHIVAGO CORE', 105, 'NC-17', 63),
#  ('MERMAID INSECTS', 104, 'NC-17', 64),
#  ('BIRDCAGE CASPER', 103, 'NC-17', 65),
#  ('IMPOSSIBLE PREJUDICE', 103, 'NC-17', 65),
#  ('STRANGELOVE DESIRE', 103, 'NC-17', 65),
#  ('CHOCOLAT HARRY', 101, 'NC-17', 66),
#  ('RUNNER MADIGAN', 101, 'NC-17', 66),
#  ('WITCHES PANIC', 100, 'NC-17', 67),
#  ('DARKNESS WAR', 99, 'NC-17', 68),
#  ('PATIENT SISTER', 99, 'NC-17', 68),
#  ('PERDITION FARGO', 99, 'NC-17', 68),
#  ('REAR TRADING', 97, 'NC-17', 69),
#  ('EARLY HOME', 96, 'NC-17', 70),
#  ('ALICE FANTASIA', 94, 'NC-17', 71),
#  ('GREATEST NORTH', 93, 'NC-17', 72),
#  ('STING PERSONAL', 93, 'NC-17', 72),
#  ('APACHE DIVINE', 92, 'NC-17', 73),
#  ('CARIBBEAN LIBERTY', 92, 'NC-17', 73),
#  ('ENCOUNTERS CURTAIN', 92, 'NC-17', 73),
#  ('MYSTIC TRUMAN', 92, 'NC-17', 73),
#  ('NATIONAL STORY', 92, 'NC-17', 73),
#  ('SUNDANCE INVASION', 92, 'NC-17', 73),
#  ('LICENSE WEEKEND', 91, 'NC-17', 74),
#  ('FORWARD TEMPLE', 90, 'NC-17', 75),
#  ('GLEAMING JAWBREAKER', 89, 'NC-17', 76),
#  ('BANG KWAI', 87, 'NC-17', 77),
#  ('SLEUTH ORIENT', 87, 'NC-17', 77),
#  ('EARTH VISION', 85, 'NC-17', 78),
#  ('ENDING CROWDS', 85, 'NC-17', 78),
#  ('GRAIL FRANKENSTEIN', 85, 'NC-17', 78),
#  ('VARSITY TRIP', 85, 'NC-17', 78),
#  ('WONKA SEA', 85, 'NC-17', 78),
#  ('IDOLS SNATCHERS', 84, 'NC-17', 79),
#  ('ISLAND EXORCIST', 84, 'NC-17', 79),
#  ('HUSTLER PARTY', 83, 'NC-17', 80),
#  ('NONE SPIKING', 83, 'NC-17', 80),
#  ('ROMAN PUNK', 81, 'NC-17', 81),
#  ('INSIDER ARIZONA', 78, 'NC-17', 82),
#  ('LANGUAGE COWBOY', 78, 'NC-17', 82),
#  ('ENEMY ODDS', 77, 'NC-17', 83),
#  ('FELLOWSHIP AUTUMN', 77, 'NC-17', 83),
#  ('MEMENTO ZOOLANDER', 77, 'NC-17', 83),
#  ('MOD SECRETARY', 77, 'NC-17', 83),
#  ('BOONDOCK BALLROOM', 76, 'NC-17', 84),
#  ('COMFORTS RUSH', 76, 'NC-17', 84),
#  ('DESIRE ALIEN', 76, 'NC-17', 84),
#  ('HAUNTED ANTITRUST', 76, 'NC-17', 84),
#  ('BALLOON HOMEWARD', 75, 'NC-17', 85),
#  ('CALIFORNIA BIRDS', 75, 'NC-17', 85),
#  ('INFORMER DOUBLE', 74, 'NC-17', 86),
#  ('JUMPING WRATH', 74, 'NC-17', 86),
#  ('LUKE MUMMY', 74, 'NC-17', 86),
#  ('MAGUIRE APACHE', 74, 'NC-17', 86),
#  ('PEARL DESTINY', 74, 'NC-17', 86),
#  ('GODFATHER DIARY', 73, 'NC-17', 87),
#  ('RANDOM GO', 73, 'NC-17', 87),
#  ('BOWFINGER GABLES', 72, 'NC-17', 88),
#  ('PRINCESS GIANT', 71, 'NC-17', 89),
#  ('CLUE GRAIL', 70, 'NC-17', 90),
#  ('GUNFIGHT MOON', 70, 'NC-17', 90),
#  ('FLYING HOOK', 69, 'NC-17', 91),
#  ('ARK RIDGEMONT', 68, 'NC-17', 92),
#  ('HUMAN GRAFFITI', 68, 'NC-17', 92),
#  ('NORTH TEQUILA', 67, 'NC-17', 93),
#  ('FREDDY STORM', 65, 'NC-17', 94),
#  ('HUNTING MUSKETEERS', 65, 'NC-17', 94),
#  ('CRAFT OUTFIELD', 64, 'NC-17', 95),
#  ('ALADDIN CALENDAR', 63, 'NC-17', 96),
#  ('ARABIA DOGMA', 62, 'NC-17', 97),
#  ('MARS ROMAN', 62, 'NC-17', 97),
#  ('CAMELOT VACATION', 61, 'NC-17', 98),
#  ('CASSIDY WYOMING', 61, 'NC-17', 98),
#  ('PHANTOM GLORY', 60, 'NC-17', 99),
#  ('PITY BOUND', 60, 'NC-17', 99),
#  ('DANCES NONE', 58, 'NC-17', 100),
#  ('CRANES RESERVOIR', 57, 'NC-17', 101),
#  ('STORM HAPPINESS', 57, 'NC-17', 101),
#  ('WOLVES DESIRE', 55, 'NC-17', 102),
#  ('BENEATH RUSH', 53, 'NC-17', 103),
#  ('CABIN FLASH', 53, 'NC-17', 103),
#  ('GUMP DATE', 53, 'NC-17', 103),
#  ('CADDYSHACK JEDI', 52, 'NC-17', 104),
#  ('SPARTACUS CHEAPER', 52, 'NC-17', 104),
#  ('WESTWARD SEABISCUIT', 52, 'NC-17', 104),
#  ('HALL CASSIDY', 51, 'NC-17', 105),
#  ('SIMON NORTH', 51, 'NC-17', 105),
#  ('ADAPTATION HOLES', 50, 'NC-17', 106),
#  ('ZORRO ARK', 50, 'NC-17', 106),
#  ('DOORS PRESIDENT', 49, 'NC-17', 107),
#  ('HEAVENLY GUN', 49, 'NC-17', 107),
#  ('ODDS BOOGIE', 48, 'NC-17', 108),
#  ('STEPMOM DREAM', 48, 'NC-17', 108),
#  ('SUNSET RACER', 48, 'NC-17', 108),
#  ('HANOVER GALAXY', 47, 'NC-17', 109),
#  ('ALIEN CENTER', 46, 'NC-17', 110)]

# %% [markdown]
# ##### 3. How many films are there for each of the categories in the category table? Hint: Use appropriate join between the tables "category" and "film_category".

# %%
# %%sql
# select name as category_name, count(*) as num_films
# from sakila.category inner join sakila.film_category using (category_id)
# group by name
# order by num_films desc;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 16 rows affected.
# [('Sports', 74),
#  ('Foreign', 73),
#  ('Family', 69),
#  ('Documentary', 68),
#  ('Animation', 66),
#  ('Action', 64),
#  ('New', 63),
#  ('Drama', 62),
#  ('Games', 61),
#  ('Sci-Fi', 61),
#  ('Children', 60),
#  ('Comedy', 58),
#  ('Classics', 57),
#  ('Travel', 57),
#  ('Horror', 56),
#  ('Music', 51)]

# %% [markdown]
# ##### 4. Which actor has appeared in the most films? Hint: You can create a join between the tables "actor" and "film actor" and count the number of times an actor appears.

# %%
# %%sql
# select actor.actor_id, actor.first_name, actor.last_name,
# count(actor_id) as film_count
# from sakila.actor join sakila.film_actor using (actor_id)
# group by actor_id
# order by film_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 1 rows affected.
# [(107, 'GINA', 'DEGENERES', 42)]

# %% [markdown]
# ##### 5. Which is the most active customer (the customer that has rented the most number of films)? Hint: Use appropriate join between the tables "customer" and "rental" and count the rental_id for each customer.

# %%
# %%sql
# select customer.*, count(rental_id) as rental_count
# from sakila.customer join sakila.rental using (customer_id)
# group by customer_id
# order by rental_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 1 rows affected.
# [(148, 1, 'ELEANOR', 'HUNT', 'ELEANOR.HUNT@sakilacustomer.org', 152, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20), 46)]

# %% [markdown]
# ##### Bonus: Which is the most rented film? (The answer is Bucket Brotherhood).

# %%
# %%sql
# select film.title, count(rental_id) as rental_count
# from sakila.film inner join sakila.inventory using (film_id)
# inner join sakila.rental using (inventory_id)
# group by film_id
# order by rental_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/sakila
# 1 rows affected.
# [('BUCKET BROTHERHOOD', 34)]
